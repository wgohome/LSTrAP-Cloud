# %% [markdown]
# <a href="https://colab.research.google.com/github/tqiaowen/LSTrAP-Cloud/blob/master/mod_download_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1. Download Script
# This script is based on the original download script found at https://github.com/wirriamm/CoNeGC/blob/master/1_Download_scripts_30Jan.ipynb, obtained on 30 January 2020.

# %% [markdown]
# # Getting started
#
#
#
# 1.   Create folder that you want to work in on Google Drive
# 2.   Download CDS file of the organism that you are working with into the folder
# 3.   Create a file containint the list of SRA runIDs that you want to download

# %%
#@title Mount Google Drive

#Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# !rm -rf /content/sample_data
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ####Import modules

# %%
#Import modules
import os
import time
from datetime import datetime as dt
import scipy.stats as stats
import json
import math
import re
import ast
import datetime

# %% [markdown]
# ####User input of variables

# %%
#@title Input form {display-mode: "form"}

#@markdown Enter the species name in the format "_**Genus_species**_", Eg: '_**Elaeis_guineensis**_'

#@markdown The folder name in your Google Drive main directory should also go by this name.

species_name = 'Nta' #@param {type: 'string'}

#@markdown ---

#@markdown File name for Run Table (with extension), stored in Google Drive folder.

#@markdown Eg: '_**RunTable_Elaeis_guineensis.txt**_'

RunTable_file = 'runid_Nta.txt' #@param {type: 'string'}

#@markdown ---

#@markdown File name for CDS file (with extension), stored in Google Drive folder.

#@markdown Eg: '_**cds.selected_transcript.egu.fasta.gz**_'

cds_fasta_file = 'GCF_000715135.1_Nta-TN90_cds_from_genomic.fna.gz' #@param {type: 'string'}

#@markdown ---

#@markdown Specify download mode

download_mode = "B. Continue from previous run" #@param ["A. Start fresh run", "B. Continue from previous run"]
download_mode = download_mode[0]

if download_mode == "B":
  Date_initiated = '2020-01-31' #@param {type: 'date'}
  date = Date_initiated

# %% [markdown]
# ####Install Dependencies, Initialise Variables and Directories

# %%
#Create Dependencies directory
if os.path.exists('/content/Dependencies') == False:
  os.mkdir('/content/Dependencies')
  os.chdir('/content/Dependencies')
  print('Dependencies directory created.')
  #Download and install kallisto
  os.system('wget \'https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz\'')
  os.system('tar -xf kallisto_linux-v0.46.0.tar.gz')
  if os.path.exists('kallisto/kallisto'):
    print('kallisto installed.')
    # !cp kallisto/kallisto /bin/kallisto
  else:
    print('kallisto not found.')
# Out:
# Dependencies directory created.
# kallisto installed.

# %%
#Define paths
working_dir_path = "/content/gdrive/My Drive/Projects/William_2019/" + species_name + "/"
working_dir_path_ter = "/content/gdrive/My\ Drive/Projects/William_2019/" + species_name + "/"
  #Note: "\(whitespace)" is needed when we are calling shell command as a string via os.system
RunTablePath = working_dir_path + RunTable_file
cds_fasta_path = working_dir_path_ter + cds_fasta_file

# %%
#Make new directory for this execution of the script if user chooses option "A"
os.chdir(working_dir_path)

if download_mode == "A":
  date = str(dt.now().date())
  files = os.listdir(working_dir_path)
  try:
      os.mkdir(working_dir_path + date + "_01")
      print(date + "_01 directory has been created.") 
  except FileExistsError:
      filename = max([filename for filename in files if date in filename])
      file_serial_int = int(filename[-2:]) + 1
      if 1 < file_serial_int < 10:
          file_serial_str = "0" + str(file_serial_int)
      elif 10 <= file_serial_int < 100:
          file_serial_str = str(file_serial_int)
          
      os.mkdir(working_dir_path + date + "_" + file_serial_str)
      print(date + "_" + file_serial_str + " directory has been created.")
  except:
      print("Directory failed to be created.")

#Calls the most recent directory
#Will start from here for Option "B"
files = os.listdir(working_dir_path)
filename = max([filename for filename in files if date in filename])
execution_dir_path = working_dir_path + filename + "/"
execution_dir_path_ter = working_dir_path_ter + filename + "/"

# %%
#Download report
#Create a tab-separated .txt logfile that stores time and progress in this workflow
os.chdir(execution_dir_path)
#species_name = (RunTablePath.split('/')[-1]).split('_',1)[1][:-4]
download_report_name = "Download_report_" + species_name + "_" + date + ".txt"

if os.path.exists(download_report_name):
  pass
  #For Option B, Download report will be read later in the for loop

else:
  #Create new download report
  download_report = open(download_report_name, "a+")
  download_report.write("Run ID\tLibrary Layout\tStatus\tFile size\tTimestamp\tKallisto time (s)\tn_processed\tn_pseudoaligned\tp_pseudoaligned\t%genes mapped\n")
  download_report.close()

# %%
#Create kallisto index
kallisto_index_path_ter = execution_dir_path_ter + "index_file_" + species_name #to be created by kallisto
kallisto_index_path = execution_dir_path + "index_file_" + species_name

if os.path.exists(kallisto_index_path):
  print("Kallisto index already present for " + species_name + ".")
else:
  index_start = time.time()
  # os.system(kallisto_path + " index -i " + kallisto_index_path_ter + " " + cds_fasta_path)
  # !kallisto index -i $kallisto_index_path_ter $cds_fasta_path
  if os.path.exists(kallisto_index_path):
    print("Kallisto index created for " + species_name + ".")
    print("Time to create kallisto index:", time.time()-index_start)
  else:
    print("Kallisto index not found for " + species_name + ".")
# Out:
# Kallisto index already present for Nta.

# %% [markdown]
# ####Download functions

# %%
#Functions#############################################################

def get_ftp_links(RunID):
  '''(str)->(str,str)
  Return ftp link in the paired and unpaired format for the RunID specified
  '''
  dir2 = ""
  if 9 < len(RunID) <= 12:
      dir2 = "0"*(12 - len(RunID)) + RunID[-(len(RunID)-9):] + "/"
  dirs = RunID[:6] + "/" + dir2 + RunID
  ftp_link_paired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + "_1.fastq.gz"
  ftp_link_unpaired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + ".fastq.gz"
  return ftp_link_paired, ftp_link_unpaired

######################################################################

def dlsize(RunID):
  """(str)->(str)
  Returns size of downloaded file obtained from the log
  """
  ll= open(RunID +".log", "r").readlines()[-1].split(" ")
  con = []
  for i in ll:
    if i != '':
      con.append(i)
    if len(con) >= 4:
      break
  return con[-1]

######################################################################

def kallisto_stream(RunID):
  '''(str)->(float,str,str,str,str)
  Runs kallisto quant on streamed fastq file for each RunID, streaming the unpaired file first. If streaming for unpaired file fails, streaming will be attempted for paired file.
  If both streaming for unpaired and paired files are unsuccessful, i.e. curl: (78) RETR response: 550; file probably does not exist on server and subsequent attempts will be aborted.
  For streaming (curl command):
    Streams only the first 1M bytes of data.
    Ensures that:
      Download speed not < 1x10^9 Bytes for 30 s
      Maximum time taken = 600 s = 10 min
    If these speed/time are not met, download is terminated and restarted for a total of 3 tries.
  '''
  RunID_file_path = execution_dir_path + RunID + "/"
  paired, unpaired = get_ftp_links(RunID)
  layout = "Layout unknown"
  for i in range(3): #try downloading at most 3 times
    kallisto_start = time.time()
    timestamp = datetime.datetime.now()
    # Dl first 1m bytes, max time 600s, speed limit ~1gb for 30s, send stderr to RunID.log
    if layout == "Paired":
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
    else:
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $unpaired 2> $RunID'.log')
      if 'curl: (78)' not in open(RunID + '.log','r').read():
       layout = "Single"
      else:
        # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
        if 'curl: (78)' in open(RunID + '.log','r').read():
          size = dlsize(RunID)
          # !rm $RunID".log"
          print(RunID + '[i=' + str(i) + ']: File not found. Download aborted.')
          layout = "N/A"
          status = "File not found"
          kallisto_end = time.time()
          break
        layout = "Paired"
    kallisto_end = time.time()

    #check for stderr logs, if absent, first 1GB file download is complete
    size = dlsize(RunID)
    if 'curl: (28)' not in open(RunID + '.log','r').read(): #if no slow dl speed error, acccept 
      # !rm $RunID".log"
      status = "Downloaded"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is acceptable.')
      break
    
    if RunID + '.log' in os.listdir(execution_dir_path): #remove stderr log file before contining to the next attempt of download
      # !cp $RunID".log" $RunID"_copy.log"
      # !rm $RunID".log"
      status = "Download speed/time not accepted"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is not accepted.')
  
  #If download still incomplete, use the last file saved
  kallisto_time = round(kallisto_end - kallisto_start, 4)
  
  return kallisto_time, layout, status, size, timestamp

######################################################################

def get_ListOfRunID(RunTablePath):
  with open(RunTablePath,"r") as RunTable:
    ListOfRunID = [RunID.strip().upper() for RunID in RunTable.readlines()]
  if "RUNID" in ListOfRunID[0]: #If input file has header, exclude header
    ListOfRunID = ListOfRunID[1:]
  return ListOfRunID

######################################################################

def open_download_report():
  with open(download_report_name, "r") as download_report:
    download_lines = download_report.readlines()
  download_entries = [line.strip().split("\t") for line in download_lines]

  return download_lines, download_entries

######################################################################

def get_comments_index(download_lines):
  hex_line_indices = [download_lines.index(line) for line in download_lines if "#" in line]
  started_indices = [index for index in hex_line_indices if "started" in download_lines[index]]
  completed_indices = [index for index in hex_line_indices if "completed" in download_lines[index]]

  return hex_line_indices, started_indices, completed_indices

######################################################################

def get_failed_RunID(mode_type):
  '''
  Opens Download Report;
  Collate failed RunIDs from the latest COMPLETED j loop.
  '''
  if mode_type == "A": #CALLED WHEN MOVING ON TO THE NEXT J LOOP
    started_index = -1
  elif mode_type == "B": #CALLED WHEN REDOWNLOADING (j=1 or 2) WITH MODE B
    started_index = -2
  #Need to reopen download report to compile failed RunIDs
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  
  j_head_index = started_indices[started_index] # If 1<=j<=2, then 2<=len(started_indices)<=3

  # Find failed RunIDs within last completed j loop, in chronological order
  list_of_failed_RunID = []
  for index in range(j_head_index, completed_indices[-1]):
    if index not in hex_line_indices and download_entries[index][2] == "Download speed/time not accepted":
      list_of_failed_RunID.append(download_entries[index][0])

  return list_of_failed_RunID

######################################################################


def get_j():
  '''
  Get the current j loop download was paused at.
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  j = len(completed_indices)
  return j

######################################################################

def get_RunID_start(RunID_queue):
  '''
  * CALLED ONCE WHEN REDOWNLOADING WITH MODE B ONLY *

  Checks from the bottom of Download Report upwards until the lastest #start.
  Takes the latest RunID.
  RunID_start_index will be the index of the next RunID in RunID_queue.
  If all RunID in queue completed, index will simply = to len(RunID_queue),
  will move on to next j loop
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)

  for i in range((len(download_entries) - 1), (started_indices[-1]), -1):
    if i not in hex_line_indices:
      RunID_latest = download_entries[i][0]
      break

  try:
    RunID_start_index = RunID_queue.index(RunID_latest) + 1
  except:
    RunID_start_index = 0 # len(RunID_queue) will also be 0, move on to next j loop. 
    print("No RunID_start_index generated.")

  return RunID_start_index

######################################################################

def update_download_report(to_print):
  with open(download_report_name, "a+") as download_report:
    download_report.write(to_print)

######################################################################

def json_extract(RunID_file_path):
  """(str)->(str,str,str,str,str)
  Extracts info from run_info.json
  """
  kal_json = ast.literal_eval(open(RunID_file_path + "run_info.json", "r").read())
  n_processed = str(kal_json["n_processed"])
  n_pseudoaligned = str(kal_json["n_pseudoaligned"])
  p_pseudoaligned = str(kal_json["p_pseudoaligned"])
  return n_processed, n_pseudoaligned, p_pseudoaligned

######################################################################

def abundance(RunID_file_path):
  """(str)->(str)
  Computes percentage of genes mapped
  """
  with open(RunID_file_path + "abundance.tsv", "r") as abun:
    abun.readline()
    tpmlist = [line.strip("\n").split("\t")[-1] for line in abun.readlines()]
    tpmval = [val for val in tpmlist if val != "0" and val != "-nan"]
    return str(round((len(tpmval)/len(tpmlist))*100 , 1)) + "%"

######################################################################

def download_loop(RunID_start_index, RunID_queue):
  '''
  Execute inner download_loop i=3 for all RunIDs in RunID_queue;
  Updates download report as each RunID is processed.
  '''
  for index in range(RunID_start_index, len(RunID_queue)):
    RunID = RunID_queue[index]
    print()
    print("-"*40)
    print()
    job_queue = index + 1
    total_queue = len(RunID_queue)
    print('Processing ' + str(job_queue) + "/" + str(total_queue) + ": " + RunID)

    RunID_file_path = execution_dir_path + RunID + "/"
    if os.path.exists(RunID_file_path) == False:
      os.mkdir(RunID_file_path) #Directory to store kallisto files of each RunID
    download_status = [RunID, "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A"]
    '''
    *Download Report Headers*
    Run ID | Library Layout | Status | File size | Timestamp | Kallisto time(s) | n_processed | n_pseudoaligned | p_pseudoaligned | %genes mapped

    *Possible output for "Method"*
    download_status[2]
      "N/A" -> No streaming attempted yet
      "Downloaded" -> Successfully streamed and quantify single/paired-end data
      "File not found" -> FASTQ file not found on server
      "Download speed/time not accepted" -> Failed to stream at a satisfactory speed
    '''
    #Streaming method
    kallisto_time, layout, status, size, timestamp = kallisto_stream(RunID)
    if os.path.exists(RunID_file_path + "run_info.json"):
      download_status[1] = layout
      download_status[2] = status
      download_status[3] = size
      download_status[4] = str(timestamp)
      download_status[5] = str(kallisto_time)
      n_processed, n_pseudoaligned, p_pseudoaligned = json_extract(RunID_file_path)
      download_status[6] = n_processed
      download_status[7] = n_pseudoaligned
      download_status[8] = p_pseudoaligned
      download_status[9] = abundance(RunID_file_path)

    else:
      print(RunID + ": Missing kallisto output")

    update_download_report("\t".join(download_status) + "\n")

  return True

######################################################################

def stringS(col, val):
  collist = [7, 12, 10,16]
  length = collist[col] - len(str(val))
  return int(length/2)*" "+str(val)+round(length/2)*" "+"|"

######################################################################

# %%
ListOfRunID = get_ListOfRunID(RunTablePath)

# Specify variables for mode A or B

if download_mode == "A":
  j, RunID_start_index = 0, 0
  RunID_queue = ListOfRunID

elif download_mode == "B":
  j = get_j()

  if j == 3:
    RunID_queue = [] #End download. j loop completed thrice.
  else:
    if j == 0:
      RunID_queue = ListOfRunID
    elif 1 <= j <= 2:
      RunID_queue = get_failed_RunID(download_mode)
    if RunID_queue == []: # End j loop if no more failed RunID.
      j = 3
  
  RunID_start_index = get_RunID_start(RunID_queue)
  update_download_report("#Download resumed\n")

# %% [markdown]
# ####Download Loop
#
# *   List item
# *   List item

# %%
#@title Code for Download Loop

# Loop through j x i times down the RunID_queue

for loop in range(j,3):
  print("\n" + "-"*40 + "\n")
  if RunID_start_index == 0:
    print("Download attempt %s"%(loop+1))
    update_download_report("#Download attempt %s started\n" % (loop+1))
  else:
    print("Download attempt %s resumed"%(j+1))
  
  download_loop(RunID_start_index, RunID_queue)
  update_download_report("#Download attempt %s completed\n" % (loop+1))

  #Reset RunID_start_index and RunID_queue
  RunID_start_index = 0
  RunID_queue = get_failed_RunID("A")
  if RunID_queue == []: # End j loop if no more failed RunID.
      print("All RunIDs have been successfully downloaded.")
      break
print("Download complete.")
with open(download_report_name, "r") as download_report:
  file_content = download_report.read()
  file_error = [(a.start(),a.end()) for a in list(re.finditer('File not found', file_content))]
  file_success = [(a.start(),a.end()) for a in list(re.finditer('Downloaded', file_content))]
  print("| Total | Downloaded | Rejected | File not found |\n|"\
        + stringS(0,len(get_ListOfRunID(RunTablePath)))\
        + stringS(1,len(file_success))\
        + stringS(2,len(get_ListOfRunID(RunTablePath))-len(file_success)-len(file_error))\
        + stringS(3,len(file_error)))
# Out:
# ----------------------------------------
#
# Download attempt 1 resumed
#
# ----------------------------------------
#
# Processing 1034/1060: SRR8727683
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2b0a000 @  0x7ffa577771e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ffa56793b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x3046000 @  0x7fdfde4801e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdfdd49cb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,660,386 reads, 8,834,091 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 970 rounds
#
# SRR8727683[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1035/1060: SRR6374516
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x18a0000 @  0x7fbf0e7de1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fbf0d7fab97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1bb6000 @  0x7f03753311e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f037434db97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,488,469 reads, 10,077,955 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 975 rounds
#
# SRR6374516[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1036/1060: SRR8727650
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x22f2000 @  0x7fa9419081e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa940924b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2ae4000 @  0x7f1d8eb4e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1d8db6ab97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,652,330 reads, 8,541,201 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 899 rounds
#
# SRR8727650[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1037/1060: SRR8727671
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1b64000 @  0x7f59ecce21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f59ebcfeb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x23b6000 @  0x7f012e60d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f012d629b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,941,077 reads, 8,760,501 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 939 rounds
#
# SRR8727671[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1038/1060: SRR8727661
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x3102000 @  0x7f6046d241e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6045d40b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1e96000 @  0x7fe50af381e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe509f54b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,026,756 reads, 9,041,419 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 880 rounds
#
# SRR8727661[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1039/1060: SRR8727672
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1640000 @  0x7ff7e75b91e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff7e65d5b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2c50000 @  0x7f46e3c6a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f46e2c86b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,660,124 reads, 7,901,164 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 930 rounds
#
# SRR8727672[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1040/1060: SRR8727677
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2728000 @  0x7f6db5c821e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6db4c9eb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x16b8000 @  0x7f87196d01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f87186ecb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,683,535 reads, 8,915,207 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,016 rounds
#
# SRR8727677[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1041/1060: SRR8727665
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2514000 @  0x7f798fafd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f798eb19b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1d9a000 @  0x7f501de2a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f501ce46b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,104,230 reads, 8,753,029 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 876 rounds
#
# SRR8727665[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1042/1060: SRR8727670
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x3034000 @  0x7f7c30ed11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7c2feedb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1dc2000 @  0x7f1f45a3c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1f44a58b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,196,026 reads, 9,162,889 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,014 rounds
#
# SRR8727670[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1043/1060: SRR8727689
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x30c2000 @  0x7f61a30841e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f61a20a0b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x138e000 @  0x7fd5de2171e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd5dd233b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,632,459 reads, 8,837,263 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 864 rounds
#
# SRR8727689[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1044/1060: SRR8727655
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x14f0000 @  0x7f52999651e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5298981b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2144000 @  0x7ff4cb03c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff4ca058b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,929,307 reads, 9,137,853 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 861 rounds
#
# SRR8727655[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1045/1060: SRR8727667
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x17b6000 @  0x7f3576aff1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3575b1bb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1a1a000 @  0x7f60ef81e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f60ee83ab97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,644,967 reads, 8,791,315 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 894 rounds
#
# SRR8727667[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1046/1060: SRR8727675
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x32bc000 @  0x7f8518ebe1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8517edab97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1388000 @  0x7f5e3f9f81e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5e3ea14b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,158,407 reads, 7,778,811 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 939 rounds
#
# SRR8727675[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1047/1060: SRR8727681
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x264a000 @  0x7f65de0391e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f65dd055b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x131c000 @  0x7f5a9168c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5a906a8b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,653,788 reads, 8,864,445 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 877 rounds
#
# SRR8727681[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1048/1060: SRR4039546
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2530000 @  0x7f3244ca01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3243cbcb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1d24000 @  0x7fa9fa4741e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa9f9490b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,824,144 reads, 8,342,445 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 941 rounds
#
# SRR4039546[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1049/1060: SRR8727649
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1fae000 @  0x7f071550e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f071452ab97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x313a000 @  0x7f1caad7c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1ca9d98b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,645,374 reads, 8,827,884 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 944 rounds
#
# SRR8727649[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1050/1060: SRR8727652
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1bb0000 @  0x7fecefe141e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7feceee30b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x15b8000 @  0x7efe64db61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7efe63dd2b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,203,190 reads, 8,867,762 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,026 rounds
#
# SRR8727652[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1051/1060: SRR8727654
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2168000 @  0x7f87fbec41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f87faee0b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1952000 @  0x7ffb9daaf1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ffb9cacbb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,933,405 reads, 8,963,166 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 863 rounds
#
# SRR8727654[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1052/1060: SRR8727656
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2b3c000 @  0x7f7b4b9dd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7b4a9f9b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x29ec000 @  0x7efc567441e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7efc55760b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,616,000 reads, 8,826,444 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 958 rounds
#
# SRR8727656[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1053/1060: SRR8727658
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2072000 @  0x7fd61164e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd61066ab97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1dee000 @  0x7f20188fd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2017919b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,031,365 reads, 8,763,269 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 992 rounds
#
# SRR8727658[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1054/1060: SRR8727663
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x3032000 @  0x7f6a93a851e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6a92aa1b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x3148000 @  0x7fa6d4e9b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa6d3eb7b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,821,645 reads, 8,135,924 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 982 rounds
#
# SRR8727663[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1055/1060: SRR8727664
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x17e2000 @  0x7fc68a2591e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc689275b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x267a000 @  0x7ff8e5df51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff8e4e11b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,913,178 reads, 8,808,603 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 983 rounds
#
# SRR8727664[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1056/1060: SRR8727673
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2a06000 @  0x7f807aadd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8079af9b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2b6e000 @  0x7f62a3a251e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f62a2a41b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,801,102 reads, 7,054,202 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 890 rounds
#
# SRR8727673[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1057/1060: SRR8727680
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x24a0000 @  0x7f73b2f621e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f73b1f7eb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1e9a000 @  0x7f267bb111e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f267ab2db97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,634,441 reads, 8,880,065 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,079 rounds
#
# SRR8727680[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1058/1060: SRR8727691
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1b50000 @  0x7fa1555771e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa154593b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x273a000 @  0x7f1e7188b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1e708a7b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,212,209 reads, 8,758,871 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 917 rounds
#
# SRR8727691[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1059/1060: SRR8727692
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2782000 @  0x7f316a8b41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f31698d0b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x2f96000 @  0x7f47cc3e01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f47cb3fcb97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,134,642 reads, 8,932,647 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 958 rounds
#
# SRR8727692[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 1060/1060: SRR8935703
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x21bc000 @  0x7fee392471e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fee38263b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 84,255
# [index] number of k-mers: 57,392,379
# tcmalloc: large alloc 1610612736 bytes == 0x1b0e000 @  0x7f7c642fb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7c63317b97 0x452a59
# [index] number of equivalence classes: 218,337
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,905,345 reads, 10,350,941 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 932 rounds
#
# SRR8935703[i=0]: Download speed/time is acceptable.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-aca214699692> in <module>()
#      13   #Reset RunID_start_index and RunID_queue
#      14   RunID_start_index = 0
# ---> 15   RunID_queue = get_failed_RunID("A")
#      16   if RunID_queue == []: # End j loop if no more failed RunID.
#      17       print("All RunIDs have been successfully downloaded.")
#
# <ipython-input-9-5329b347f490> in get_failed_RunID(mode_type)
#     132   list_of_failed_RunID = []
#     133   for index in range(j_head_index, completed_indices[-1]):
# --> 134     if index not in hex_line_indices and download_entries[index][2] == "Download speed/time not accepted":
#     135       list_of_failed_RunID.append(download_entries[index][0])
#     136
#
# IndexError: list index out of range
