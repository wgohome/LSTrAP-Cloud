# %% [markdown]
# <a href="https://colab.research.google.com/github/tqiaowen/LSTrAP-Cloud/blob/master/mod_download_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Downloading FASTQ files from ENA
# This script is based on the original download script found [here](https://github.com/wirriamm/CoNeGC/blob/master/1_Download_scripts_30Jan.ipynb), obtained on 30 January 2020.
#
# ### What does this script do?
# This script will help you stream RNA-seq data (FASTQ files) from ENA and quantify the RNA transcript abundance using kallisto concurrently.
#
# ### What you will require
# 1. A Google Account to save your data
# 2. A folder in your Google Drive containing<br>
#   a) RunTable file<br>This file should contain the list of RunIDs that you want to download from ENA ([example]())<br>
#   b) CDS file of the organism that you are interested to work with
#
# ### Expected outputs
# 1. Kallisto index of your organism's CDS<br>
# 2. Kallisto output folders<br>
# 3. Download report<br>Summarises for each RunID the status of download, amount of data downloaded, amount of time taken for kallisto streaming and a statistics from kallisto
#
#
# ### Bonus tips?
# 1. If you noticed that the file has not been downloaded successfully ("Download speed/time not accepted"), not to worry, the script will attempt to download it again.
# 2. Download got interrupted due to runtime disconnecting? Just re-run the script with 'Option B' (Step 1.2, part 5) and specify the date when you started the download.
# 3. If you encoutner any issues, please raise an issue on [Github](https://github.com/tqiaowen/LSTrAP-Cloud) or contact us [here](mailto:qiaowen001@e.ntu.edu.sg).

# %%
#@markdown ####1.1 Mount Google Drive and import python modules

#Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# !rm -rf /content/sample_data

#Import modules
import os
import time
from datetime import datetime as dt
import scipy.stats as stats
import json
import math
import re
import ast
import datetime
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ####User input of variables

# %%
#@title 1.2 Input form {display-mode: "form"}

#@markdown 1) Enter the absolute path for the folder you are going to work with. Tip: After mounting your Google Drive, right click on the file and copy path.<br>
#@markdown <html><img src = 'https://github.com/tqiaowen/LSTrAP-Cloud/blob/master/img/folder_path.png?raw=true', alt = 'Copy file path' width=360 height=287></html>

in_dir = '/content/gdrive/My Drive/Projects/William_2019/Nta_Edward' #@param {type: 'string'}

#@markdown ---

#@markdown 2) Enter the species name. Eg. _Nicotiana tabacum_ can be shortened to **Nta**

species_name = 'Nta' #@param {type: 'string'}

#@markdown ---

#@markdown 3) File name for Run Table (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**runid_Nta.txt**_'

RunTable_file = 'runid_Nta.txt' #@param {type: 'string'}

#@markdown ---

#@markdown 4) File name for CDS file (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**GCF_000715135.1_Ntab-TN90_cds_from_genomic.fna.gz**_'

cds_fasta_file = 'Nitab-v4.5_cDNA_Edwards2017.fasta' #@param {type: 'string'}

#@markdown ---

#@markdown 5) Specify download mode

download_mode = "A. Start fresh run" #@param ["A. Start fresh run", "B. Continue from previous run"]
download_mode = download_mode[0]

if download_mode == "B":
  Date_initiated = '2020-02-14' #@param {type: 'date'}
  date = Date_initiated

# %%
#@markdown 1.3 Install Dependencies, Initialise Variables and Directories

#Create Dependencies directory
if os.path.exists('/content/Dependencies') == False:
  os.mkdir('/content/Dependencies')
  os.chdir('/content/Dependencies')
  print('Dependencies directory created.')
  #Download and install kallisto
  os.system('wget \'https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz\'')
  os.system('tar -xf kallisto_linux-v0.46.0.tar.gz')
  if os.path.exists('kallisto/kallisto'):
    print('kallisto installed.')
    # !cp kallisto/kallisto /bin/kallisto
  else:
    print('kallisto not found.')

#Define paths
working_dir_path = "/content/gdrive/My Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
working_dir_path_ter = "/content/gdrive/My\ Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
  #Note: "\(whitespace)" is needed when we are calling shell command as a string via os.system
RunTablePath = working_dir_path + RunTable_file
cds_fasta_path = working_dir_path_ter + cds_fasta_file    

#Make new directory for this execution of the script if user chooses option "A"
os.chdir(working_dir_path)

if download_mode == "A":
  date = str(dt.now().date())
  files = os.listdir(working_dir_path)
  try:
      os.mkdir(working_dir_path + date + "_01")
      print(date + "_01 directory has been created.") 
  except FileExistsError:
      filename = max([filename for filename in files if date in filename])
      file_serial_int = int(filename[-2:]) + 1
      if 1 < file_serial_int < 10:
          file_serial_str = "0" + str(file_serial_int)
      elif 10 <= file_serial_int < 100:
          file_serial_str = str(file_serial_int)
          
      os.mkdir(working_dir_path + date + "_" + file_serial_str)
      print(date + "_" + file_serial_str + " directory has been created.")
  except:
      print("Directory failed to be created.")

#Calls the most recent directory
#Will start from here for Option "B"
files = os.listdir(working_dir_path)
filename = max([filename for filename in files if date in filename])
execution_dir_path = working_dir_path + filename + "/"
execution_dir_path_ter = working_dir_path_ter + filename + "/"

#Download report
#Create a tab-separated .txt logfile that stores time and progress in this workflow
os.chdir(execution_dir_path)
#species_name = (RunTablePath.split('/')[-1]).split('_',1)[1][:-4]
download_report_name = "Download_report_" + species_name + "_" + date + ".txt"

if os.path.exists(download_report_name):
  pass
  #For Option B, Download report will be read later in the for loop

else:
  #Create new download report
  download_report = open(download_report_name, "a+")
  download_report.write("Run ID\tLibrary Layout\tStatus\tFile size\tTimestamp\tKallisto time (s)\tn_processed\tn_pseudoaligned\tp_pseudoaligned\t%genes mapped\n")
  download_report.close()
# Out:
# 2020-02-14_01 directory has been created.

# %%
#@markdown 1.4 Create kallisto index
kallisto_index_path_ter = execution_dir_path_ter + "index_file_" + species_name #to be created by kallisto
kallisto_index_path = execution_dir_path + "index_file_" + species_name

if os.path.exists(kallisto_index_path):
  print("Kallisto index already present for " + species_name + ".")
else:
  index_start = time.time()
  # os.system(kallisto_path + " index -i " + kallisto_index_path_ter + " " + cds_fasta_path)
  # !kallisto index -i $kallisto_index_path_ter $cds_fasta_path
  if os.path.exists(kallisto_index_path):
    print("Kallisto index created for " + species_name + ".")
    print("Time to create kallisto index:", time.time()-index_start)
  else:
    print("Kallisto index not found for " + species_name + ".")
# Out:
# [build] loading fasta file /content/gdrive/My Drive/Projects/William_2019/Nta_Edward/Nitab-v4.5_cDNA_Edwards2017.fasta
# [build] k-mer length: 31
# [build] warning: clipped off poly-A tail (longer than 10)
#         from 1 target sequences
# [build] warning: replaced 4063 non-ACGUT characters in the input sequence
#         with pseudorandom nucleotides
# [build] counting k-mers ... tcmalloc: large alloc 1610612736 bytes == 0x68054000 @  0x7ff8e795c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a4ca8 0x4abe49 0x44e1d4 0x7ff8e6978b97 0x452a59
# done.
# [build] building target de Bruijn graph ...  done
# [build] creating equivalence classes ...  done
# [build] target de Bruijn graph has 1316047 contigs and contains 61223759 k-mers
#
# Kallisto index created for Nta.
# Time to create kallisto index: 247.36046409606934

# %%
#@markdown 1.5 Preparation for download<br>
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.1 Initialise download functions</html>
#Functions#############################################################

def get_ftp_links(RunID):
  '''(str)->(str,str)
  Return ftp link in the paired and unpaired format for the RunID specified
  '''
  dir2 = ""
  if 9 < len(RunID) <= 12:
      dir2 = "0"*(12 - len(RunID)) + RunID[-(len(RunID)-9):] + "/"
  dirs = RunID[:6] + "/" + dir2 + RunID
  ftp_link_paired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + "_1.fastq.gz"
  ftp_link_unpaired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + ".fastq.gz"
  return ftp_link_paired, ftp_link_unpaired

######################################################################

def dlsize(RunID):
  """(str)->(str)
  Returns size of downloaded file obtained from the log
  """
  ll= open(RunID +".log", "r").readlines()[-1].split(" ")
  con = []
  for i in ll:
    if i != '':
      con.append(i)
    if len(con) >= 4:
      break
  return con[-1]

######################################################################

def kallisto_stream(RunID):
  '''(str)->(float,str,str,str,str)
  Runs kallisto quant on streamed fastq file for each RunID, streaming the unpaired file first. If streaming for unpaired file fails, streaming will be attempted for paired file.
  If both streaming for unpaired and paired files are unsuccessful, i.e. curl: (78) RETR response: 550; file probably does not exist on server and subsequent attempts will be aborted.
  For streaming (curl command):
    Streams only the first 1M bytes of data.
    Ensures that:
      Download speed not < 1x10^9 Bytes for 30 s
      Maximum time taken = 600 s = 10 min
    If these speed/time are not met, download is terminated and restarted for a total of 3 tries.
  '''
  RunID_file_path = execution_dir_path + RunID + "/"
  paired, unpaired = get_ftp_links(RunID)
  layout = "Layout unknown"
  for i in range(3): #try downloading at most 3 times
    kallisto_start = time.time()
    timestamp = datetime.datetime.now()
    # Dl first 1m bytes, max time 600s, speed limit ~1gb for 30s, send stderr to RunID.log
    if layout == "Paired":
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
    else:
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $unpaired 2> $RunID'.log')
      if 'curl: (78)' not in open(RunID + '.log','r').read():
       layout = "Single"
      else:
        # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
        if 'curl: (78)' in open(RunID + '.log','r').read():
          size = dlsize(RunID)
          # !rm $RunID".log"
          print(RunID + '[i=' + str(i) + ']: File not found. Download aborted.')
          layout = "N/A"
          status = "File not found"
          kallisto_end = time.time()
          break
        layout = "Paired"
    kallisto_end = time.time()

    #check for stderr logs, if absent, first 1GB file download is complete
    size = dlsize(RunID)
    if 'curl: (28)' not in open(RunID + '.log','r').read(): #if no slow dl speed error, acccept 
      # !rm $RunID".log"
      status = "Downloaded"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is acceptable.')
      break
    
    if RunID + '.log' in os.listdir(execution_dir_path): #remove stderr log file before contining to the next attempt of download
      # !cp $RunID".log" $RunID"_copy.log"
      # !rm $RunID".log"
      status = "Download speed/time not accepted"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is not accepted.')
  
  #If download still incomplete, use the last file saved
  kallisto_time = round(kallisto_end - kallisto_start, 4)
  
  return kallisto_time, layout, status, size, timestamp

######################################################################

def get_ListOfRunID(RunTablePath):
  with open(RunTablePath,"r") as RunTable:
    ListOfRunID = [RunID.strip().upper() for RunID in RunTable.readlines()]
  if "RUNID" in ListOfRunID[0]: #If input file has header, exclude header
    ListOfRunID = ListOfRunID[1:]
  return ListOfRunID

######################################################################

def open_download_report():
  with open(download_report_name, "r") as download_report:
    download_lines = download_report.readlines()
  download_entries = [line.strip().split("\t") for line in download_lines]

  return download_lines, download_entries

######################################################################

def get_comments_index(download_lines):
  hex_line_indices = [download_lines.index(line) for line in download_lines if "#" in line]
  started_indices = [index for index in hex_line_indices if "started" in download_lines[index]]
  completed_indices = [index for index in hex_line_indices if "completed" in download_lines[index]]

  return hex_line_indices, started_indices, completed_indices

######################################################################

def get_failed_RunID(mode_type):
  '''
  Opens Download Report;
  Collate failed RunIDs from the latest COMPLETED j loop.
  '''
  if mode_type == "A": #CALLED WHEN MOVING ON TO THE NEXT J LOOP
    started_index = -1
  elif mode_type == "B": #CALLED WHEN REDOWNLOADING (j=1 or 2) WITH MODE B
    started_index = -2
  #Need to reopen download report to compile failed RunIDs
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  
  j_head_index = started_indices[started_index] # If 1<=j<=2, then 2<=len(started_indices)<=3

  # Find failed RunIDs within last completed j loop, in chronological order
  list_of_failed_RunID = []
  for index in range(j_head_index, completed_indices[-1]):
    if index not in hex_line_indices and download_entries[index][2] == "Download speed/time not accepted":
      list_of_failed_RunID.append(download_entries[index][0])

  return list_of_failed_RunID

######################################################################


def get_j():
  '''
  Get the current j loop download was paused at.
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  j = len(completed_indices)
  return j

######################################################################

def get_RunID_start(RunID_queue):
  '''
  * CALLED ONCE WHEN REDOWNLOADING WITH MODE B ONLY *

  Checks from the bottom of Download Report upwards until the lastest #start.
  Takes the latest RunID.
  RunID_start_index will be the index of the next RunID in RunID_queue.
  If all RunID in queue completed, index will simply = to len(RunID_queue),
  will move on to next j loop
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)

  for i in range((len(download_entries) - 1), (started_indices[-1]), -1):
    if i not in hex_line_indices:
      RunID_latest = download_entries[i][0]
      break

  try:
    RunID_start_index = RunID_queue.index(RunID_latest) + 1
  except:
    RunID_start_index = 0 # len(RunID_queue) will also be 0, move on to next j loop. 
    print("No RunID_start_index generated.")

  return RunID_start_index

######################################################################

def update_download_report(to_print):
  with open(download_report_name, "a+") as download_report:
    download_report.write(to_print)

######################################################################

def json_extract(RunID_file_path):
  """(str)->(str,str,str,str,str)
  Extracts info from run_info.json
  """
  kal_json = ast.literal_eval(open(RunID_file_path + "run_info.json", "r").read())
  n_processed = str(kal_json["n_processed"])
  n_pseudoaligned = str(kal_json["n_pseudoaligned"])
  p_pseudoaligned = str(kal_json["p_pseudoaligned"])
  return n_processed, n_pseudoaligned, p_pseudoaligned

######################################################################

def abundance(RunID_file_path):
  """(str)->(str)
  Computes percentage of genes mapped
  """
  with open(RunID_file_path + "abundance.tsv", "r") as abun:
    abun.readline()
    tpmlist = [line.strip("\n").split("\t")[-1] for line in abun.readlines()]
    tpmval = [val for val in tpmlist if val != "0" and val != "-nan"]
    return str(round((len(tpmval)/len(tpmlist))*100 , 1)) + "%"

######################################################################

def download_loop(RunID_start_index, RunID_queue):
  '''
  Execute inner download_loop i=3 for all RunIDs in RunID_queue;
  Updates download report as each RunID is processed.
  '''
  for index in range(RunID_start_index, len(RunID_queue)):
    RunID = RunID_queue[index]
    print()
    print("-"*40)
    print()
    job_queue = index + 1
    total_queue = len(RunID_queue)
    print('Processing ' + str(job_queue) + "/" + str(total_queue) + ": " + RunID)

    RunID_file_path = execution_dir_path + RunID + "/"
    if os.path.exists(RunID_file_path) == False:
      os.mkdir(RunID_file_path) #Directory to store kallisto files of each RunID
    download_status = [RunID, "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A"]
    '''
    *Download Report Headers*
    Run ID | Library Layout | Status | File size | Timestamp | Kallisto time(s) | n_processed | n_pseudoaligned | p_pseudoaligned | %genes mapped

    *Possible output for "Method"*
    download_status[2]
      "N/A" -> No streaming attempted yet
      "Downloaded" -> Successfully streamed and quantify single/paired-end data
      "File not found" -> FASTQ file not found on server
      "Download speed/time not accepted" -> Failed to stream at a satisfactory speed
    '''
    #Streaming method
    kallisto_time, layout, status, size, timestamp = kallisto_stream(RunID)
    if os.path.exists(RunID_file_path + "run_info.json"):
      download_status[1] = layout
      download_status[2] = status
      download_status[3] = size
      download_status[4] = str(timestamp)
      download_status[5] = str(kallisto_time)
      n_processed, n_pseudoaligned, p_pseudoaligned = json_extract(RunID_file_path)
      download_status[6] = n_processed
      download_status[7] = n_pseudoaligned
      download_status[8] = p_pseudoaligned
      download_status[9] = abundance(RunID_file_path)

    else:
      print(RunID + ": Missing kallisto output")

    update_download_report("\t".join(download_status) + "\n")

  return True

######################################################################

def stringS(col, val):
  collist = [7, 12, 10,16]
  length = collist[col] - len(str(val))
  return int(length/2)*" "+str(val)+round(length/2)*" "+"|"

######################################################################
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.2 Updating list of RunIDs to be downloaded</html>
ListOfRunID = get_ListOfRunID(RunTablePath)

# Specify variables for mode A or B

if download_mode == "A":
  j, RunID_start_index = 0, 0
  RunID_queue = ListOfRunID

elif download_mode == "B":
  j = get_j()

  if j == 3:
    RunID_queue = [] #End download. j loop completed thrice.
  else:
    if j == 0:
      RunID_queue = ListOfRunID
    elif 1 <= j <= 2:
      RunID_queue = get_failed_RunID(download_mode)
    if RunID_queue == []: # End j loop if no more failed RunID.
      j = 3
  
  RunID_start_index = get_RunID_start(RunID_queue)
  update_download_report("#Download resumed\n")

# %%
#@markdown 1.6 Loop to download experiments according to updated list of runIDs

# Loop through j x i times down the RunID_queue

for loop in range(j,3):
  print("\n" + "-"*40 + "\n")
  if RunID_start_index == 0:
    print("Download attempt %s"%(loop+1))
    update_download_report("#Download attempt %s started\n" % (loop+1))
  else:
    print("Download attempt %s resumed"%(j+1))
  
  download_loop(RunID_start_index, RunID_queue)
  update_download_report("#Download attempt %s completed\n" % (loop+1))

  #Reset RunID_start_index and RunID_queue
  RunID_start_index = 0
  RunID_queue = get_failed_RunID("A")
  if RunID_queue == []: # End j loop if no more failed RunID.
      print("All RunIDs have been successfully downloaded.")
      break
print("Download complete.")
with open(download_report_name, "r") as download_report:
  file_content = download_report.read()
  file_error = [(a.start(),a.end()) for a in list(re.finditer('File not found', file_content))]
  file_success = [(a.start(),a.end()) for a in list(re.finditer('Downloaded', file_content))]
  print("| Total | Downloaded | Rejected | File not found |\n|"\
        + stringS(0,len(get_ListOfRunID(RunTablePath)))\
        + stringS(1,len(file_success))\
        + stringS(2,len(get_ListOfRunID(RunTablePath))-len(file_success)-len(file_error))\
        + stringS(3,len(file_error)))
# Out:
# ----------------------------------------
#
# Download attempt 1
#
# ----------------------------------------
#
# Processing 1/1060: SRR2671859
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x13ea000 @  0x7f199453a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1993556b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,718,500 reads, 11,334,985 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 394 rounds
#
# SRR2671859[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 2/1060: SRR2671860
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2180000 @  0x7fb7532fe1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb75231ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,648,459 reads, 11,088,808 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 320 rounds
#
# SRR2671860[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 3/1060: SRR2671861
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2dbc000 @  0x7f1477cca1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1476ce6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,887,609 reads, 10,759,829 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 392 rounds
#
# SRR2671861[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 4/1060: SRR2671862
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2da8000 @  0x7fa4281d61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa4271f2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,776,756 reads, 11,099,529 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 297 rounds
#
# SRR2671862[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 5/1060: SRR2671863
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1416000 @  0x7fe5947841e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe5937a0b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,082,202 reads, 9,783,893 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 707 rounds
#
# SRR2671863[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 6/1060: SRR2671864
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1408000 @  0x7f7e366751e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7e35691b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,679,042 reads, 10,341,484 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 705 rounds
#
# SRR2671864[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 7/1060: SRR2671865
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x30ba000 @  0x7f054056c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f053f588b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,677,062 reads, 11,189,265 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 483 rounds
#
# SRR2671865[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 8/1060: SRR2671866
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1846000 @  0x7f5eb3e9c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5eb2eb8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 15,684,879 reads, 11,213,471 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 452 rounds
#
# SRR2671866[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 9/1060: SRR1040497
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3184000 @  0x7f353b7721e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f353a78eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 21,514,828 reads, 14,412,077 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 443 rounds
#
# SRR1040497[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 10/1060: SRR1040764
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a9c000 @  0x7f194fb421e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f194eb5eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,127,551 reads, 3,987,406 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 578 rounds
#
# SRR1040764[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 11/1060: SRR1040765
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1e2e000 @  0x7f882a7051e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8829721b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 5,566,935 reads, 3,750,133 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 507 rounds
#
# SRR1040765[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 12/1060: SRR1040766
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3206000 @  0x7f7fd7e8d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7fd6ea9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,020,409 reads, 4,012,111 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 511 rounds
#
# SRR1040766[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 13/1060: SRR1040767
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ee2000 @  0x7f4c21a261e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4c20a42b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 5,252,135 reads, 3,575,570 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 627 rounds
#
# SRR1040767[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 14/1060: SRR1040768
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ad4000 @  0x7fb0695131e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb06852fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 5,913,266 reads, 4,093,420 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 652 rounds
#
# SRR1040768[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 15/1060: SRR1040769
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c5e000 @  0x7fe4e40c31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe4e30dfb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 5,218,808 reads, 3,599,926 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 462 rounds
#
# SRR1040769[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 16/1060: SRR1040770
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x141c000 @  0x7f1c62dcf1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1c61debb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,091,837 reads, 4,067,339 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# SRR1040770[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 17/1060: SRR1040771
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x268e000 @  0x7f9d9b3c21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9d9a3deb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,005,103 reads, 4,056,684 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# SRR1040771[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 18/1060: SRR1040772
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20c6000 @  0x7f73cc1721e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f73cb18eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,260,204 reads, 4,329,666 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 613 rounds
#
# SRR1040772[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 19/1060: SRR1040773
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2170000 @  0x7f984a1f51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9849211b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 6,010,205 reads, 4,148,609 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 609 rounds
#
# SRR1040773[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 20/1060: SRR3193883
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x294e000 @  0x7f7794a291e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7793a45b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 192,863 reads, 121,583 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 516 rounds
#
# SRR3193883[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 21/1060: SRR3193977
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2858000 @  0x7fa6288961e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa6278b2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 117,040 reads, 73,659 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 416 rounds
#
# SRR3193977[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 22/1060: SRR3194171
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x230a000 @  0x7fd0180d21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd0170eeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 190,414 reads, 120,428 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 301 rounds
#
# SRR3194171[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 23/1060: SRR1020542
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x229c000 @  0x7fd78ff5d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd78ef79b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,191,162 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020542[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 24/1060: SRR1020543
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c70000 @  0x7f35a58221e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f35a483eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,060,320 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020543[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 25/1060: SRR1020544
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x19fa000 @  0x7fc4f42a71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc4f32c3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,305,723 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020544[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 26/1060: SRR1020545
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1de8000 @  0x7f0e488e61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0e47902b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,464,482 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020545[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 27/1060: SRR1020546
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2910000 @  0x7f47233f21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f472240eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,473,006 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020546[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 28/1060: SRR1020547
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2586000 @  0x7f555c0821e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f555b09eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,402,816 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020547[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 29/1060: SRR1020548
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2cf2000 @  0x7f4427b5f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4426b7bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,613,896 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020548[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 30/1060: SRR1020549
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2114000 @  0x7f3f3035c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3f2f378b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,855,498 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020549[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 31/1060: SRR1020550
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1766000 @  0x7fb32d2601e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb32c27cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,038,423 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020550[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 32/1060: SRR1020551
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1c78000 @  0x7f8b7e6c91e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8b7d6e5b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,891,799 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020551[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 33/1060: SRR1020552
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x23c4000 @  0x7f1ca3a641e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1ca2a80b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,176,859 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020552[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 34/1060: SRR1020553
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x287e000 @  0x7f8579c6c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8578c88b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,358,367 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020553[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 35/1060: SRR1020555
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2bb8000 @  0x7f1c469e71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1c45a03b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,886,823 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020555[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 36/1060: SRR1020556
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x21de000 @  0x7f8541cd31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8540cefb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,159,124 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020556[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 37/1060: SRR1020557
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x29d2000 @  0x7ffa44e6b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ffa43e87b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,351,443 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020557[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 38/1060: SRR1020558
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f7c000 @  0x7fdb3e10a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdb3d126b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,286,286 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020558[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 39/1060: SRR1020559
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2356000 @  0x7f8a8f4fb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8a8e517b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,141,254 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020559[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 40/1060: SRR1020560
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x307e000 @  0x7f8d784e51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8d77501b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,454,106 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020560[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 41/1060: SRR1020561
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ee4000 @  0x7f892306a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8922086b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,711,990 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR1020561[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 42/1060: SRR1664782
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x23d2000 @  0x7f7b7543a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7b74456b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x153c000 @  0x7f666a86a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6669886b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,708,630 reads, 9,244,909 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 652 rounds
#
# SRR1664782[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 43/1060: SRR2084815
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1770000 @  0x7feca631a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7feca5336b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2106000 @  0x7f3d96a1c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3d95a38b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,769,229 reads, 8,114,784 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 507 rounds
#
# SRR2084815[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 44/1060: SRR3114162
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1cd2000 @  0x7f8023c6e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8022c8ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2152000 @  0x7f1895cf11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1894d0db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,517,612 reads, 9,610,461 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 402 rounds
#
# SRR3114162[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 45/1060: SRR3114163
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17c8000 @  0x7f2ad733b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2ad6357b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2344000 @  0x7f300589c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f30048b8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,443,207 reads, 7,372,617 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 476 rounds
#
# SRR3114163[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 46/1060: SRR3114164
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x22d8000 @  0x7f2968eb51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2967ed1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2030000 @  0x7fd33ac0b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd339c27b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,689,494 reads, 9,388,974 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 388 rounds
#
# SRR3114164[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 47/1060: SRR3114165
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2fc6000 @  0x7f88137691e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8812785b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20be000 @  0x7f87f73921e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f87f63aeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,142,134 reads, 8,056,753 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 338 rounds
#
# SRR3114165[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 48/1060: SRR3114166
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2b7a000 @  0x7f2fd61cb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2fd51e7b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1996000 @  0x7f8c7817f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8c7719bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,459,812 reads, 9,904,409 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 479 rounds
#
# SRR3114166[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 49/1060: SRR3114167
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x14f4000 @  0x7f81a4cec1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f81a3d08b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1570000 @  0x7fd60bab11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd60aacdb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,581,220 reads, 9,945,617 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 429 rounds
#
# SRR3114167[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 50/1060: SRR3114168
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2d8a000 @  0x7fe2419ad1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe2409c9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2516000 @  0x7f1d2b1f41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1d2a210b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ...
