# %% [markdown]
# <a href="https://colab.research.google.com/github/tqiaowen/LSTrAP-Cloud/blob/master/mod_download_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Downloading FASTQ files from ENA
# This script is based on the original download script found [here](https://github.com/wirriamm/CoNeGC/blob/master/1_Download_scripts_30Jan.ipynb), obtained on 30 January 2020.
#
# ### What does this script do?
# This script will help you stream RNA-seq data (FASTQ files) from ENA and quantify the RNA transcript abundance using kallisto concurrently.
#
# ### What you will require
# 1. A Google Account to save your data
# 2. A folder in your Google Drive containing<br>
#   a) RunTable file<br>This file should contain the list of RunIDs that you want to download from ENA ([example]())<br>
#   b) CDS file of the organism that you are interested to work with
#
# ### Expected outputs
# 1. Kallisto index of your organism's CDS<br>
# 2. Kallisto output folders<br>
# 3. Download report<br>Summarises for each RunID the status of download, amount of data downloaded, amount of time taken for kallisto streaming and a statistics from kallisto
#
#
# ### Bonus tips?
# 1. If you noticed that the file has not been downloaded successfully ("Download speed/time not accepted"), not to worry, the script will attempt to download it again.
# 2. Download got interrupted due to runtime disconnecting? Just re-run the script with 'Option B' (Step 1.2, part 5) and specify the date when you started the download.
# 3. If you encoutner any issues, please raise an issue on [Github](https://github.com/tqiaowen/LSTrAP-Cloud) or contact us [here](mailto:qiaowen001@e.ntu.edu.sg).

# %%
#@markdown ####1.1 Mount Google Drive and import python modules

#Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# !rm -rf /content/sample_data

#Import modules
import os
import time
from datetime import datetime as dt
import scipy.stats as stats
import json
import math
import re
import ast
import datetime
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ####User input of variables

# %%
#@title 1.2 Input form {display-mode: "form"}

#@markdown 1) Enter the absolute path for the folder you are going to work with. Tip: After mounting your Google Drive, right click on the file and copy path.<br>
#@markdown <html><img src = 'https://github.com/tqiaowen/LSTrAP-Cloud/blob/master/img/folder_path.png?raw=true', alt = 'Copy file path' width=360 height=287></html>

in_dir = '/content/gdrive/My Drive/Projects/William_2019/Nta_Edward' #@param {type: 'string'}

#@markdown ---

#@markdown 2) Enter the species name. Eg. _Nicotiana tabacum_ can be shortened to **Nta**

species_name = 'Nta' #@param {type: 'string'}

#@markdown ---

#@markdown 3) File name for Run Table (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**runid_Nta.txt**_'

RunTable_file = 'runid_Nta.txt' #@param {type: 'string'}

#@markdown ---

#@markdown 4) File name for CDS file (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**GCF_000715135.1_Ntab-TN90_cds_from_genomic.fna.gz**_'

cds_fasta_file = 'Nitab-v4.5_cDNA_Edwards2017.fasta' #@param {type: 'string'}

#@markdown ---

#@markdown 5) Specify download mode

download_mode = "B. Continue from previous run" #@param ["A. Start fresh run", "B. Continue from previous run"]
download_mode = download_mode[0]

if download_mode == "B":
  Date_initiated = '2020-02-14' #@param {type: 'date'}
  date = Date_initiated

# %%
#@markdown 1.3 Install Dependencies, Initialise Variables and Directories

#Create Dependencies directory
if os.path.exists('/content/Dependencies') == False:
  os.mkdir('/content/Dependencies')
  os.chdir('/content/Dependencies')
  print('Dependencies directory created.')
  #Download and install kallisto
  os.system('wget \'https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz\'')
  os.system('tar -xf kallisto_linux-v0.46.0.tar.gz')
  if os.path.exists('kallisto/kallisto'):
    print('kallisto installed.')
    # !cp kallisto/kallisto /bin/kallisto
  else:
    print('kallisto not found.')

#Define paths
working_dir_path = "/content/gdrive/My Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
working_dir_path_ter = "/content/gdrive/My\ Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
  #Note: "\(whitespace)" is needed when we are calling shell command as a string via os.system
RunTablePath = working_dir_path + RunTable_file
cds_fasta_path = working_dir_path_ter + cds_fasta_file    

#Make new directory for this execution of the script if user chooses option "A"
os.chdir(working_dir_path)

if download_mode == "A":
  date = str(dt.now().date())
  files = os.listdir(working_dir_path)
  try:
      os.mkdir(working_dir_path + date + "_01")
      print(date + "_01 directory has been created.") 
  except FileExistsError:
      filename = max([filename for filename in files if date in filename])
      file_serial_int = int(filename[-2:]) + 1
      if 1 < file_serial_int < 10:
          file_serial_str = "0" + str(file_serial_int)
      elif 10 <= file_serial_int < 100:
          file_serial_str = str(file_serial_int)
          
      os.mkdir(working_dir_path + date + "_" + file_serial_str)
      print(date + "_" + file_serial_str + " directory has been created.")
  except:
      print("Directory failed to be created.")

#Calls the most recent directory
#Will start from here for Option "B"
files = os.listdir(working_dir_path)
filename = max([filename for filename in files if date in filename])
execution_dir_path = working_dir_path + filename + "/"
execution_dir_path_ter = working_dir_path_ter + filename + "/"

#Download report
#Create a tab-separated .txt logfile that stores time and progress in this workflow
os.chdir(execution_dir_path)
#species_name = (RunTablePath.split('/')[-1]).split('_',1)[1][:-4]
download_report_name = "Download_report_" + species_name + "_" + date + ".txt"

if os.path.exists(download_report_name):
  pass
  #For Option B, Download report will be read later in the for loop

else:
  #Create new download report
  download_report = open(download_report_name, "a+")
  download_report.write("Run ID\tLibrary Layout\tStatus\tFile size\tTimestamp\tKallisto time (s)\tn_processed\tn_pseudoaligned\tp_pseudoaligned\t%genes mapped\n")
  download_report.close()

# %%
#@markdown 1.4 Create kallisto index
kallisto_index_path_ter = execution_dir_path_ter + "index_file_" + species_name #to be created by kallisto
kallisto_index_path = execution_dir_path + "index_file_" + species_name

if os.path.exists(kallisto_index_path):
  print("Kallisto index already present for " + species_name + ".")
else:
  index_start = time.time()
  # os.system(kallisto_path + " index -i " + kallisto_index_path_ter + " " + cds_fasta_path)
  # !kallisto index -i $kallisto_index_path_ter $cds_fasta_path
  if os.path.exists(kallisto_index_path):
    print("Kallisto index created for " + species_name + ".")
    print("Time to create kallisto index:", time.time()-index_start)
  else:
    print("Kallisto index not found for " + species_name + ".")
# Out:
# Kallisto index already present for Nta.

# %%
#@markdown 1.5 Preparation for download<br>
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.1 Initialise download functions</html>
#Functions#############################################################

def get_ftp_links(RunID):
  '''(str)->(str,str)
  Return ftp link in the paired and unpaired format for the RunID specified
  '''
  dir2 = ""
  if 9 < len(RunID) <= 12:
      dir2 = "0"*(12 - len(RunID)) + RunID[-(len(RunID)-9):] + "/"
  dirs = RunID[:6] + "/" + dir2 + RunID
  ftp_link_paired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + "_1.fastq.gz"
  ftp_link_unpaired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + ".fastq.gz"
  return ftp_link_paired, ftp_link_unpaired

######################################################################

def dlsize(RunID):
  """(str)->(str)
  Returns size of downloaded file obtained from the log
  """
  ll= open(RunID +".log", "r").readlines()[-1].split(" ")
  con = []
  for i in ll:
    if i != '':
      con.append(i)
    if len(con) >= 4:
      break
  return con[-1]

######################################################################

def kallisto_stream(RunID):
  '''(str)->(float,str,str,str,str)
  Runs kallisto quant on streamed fastq file for each RunID, streaming the unpaired file first. If streaming for unpaired file fails, streaming will be attempted for paired file.
  If both streaming for unpaired and paired files are unsuccessful, i.e. curl: (78) RETR response: 550; file probably does not exist on server and subsequent attempts will be aborted.
  For streaming (curl command):
    Streams only the first 1M bytes of data.
    Ensures that:
      Download speed not < 1x10^9 Bytes for 30 s
      Maximum time taken = 600 s = 10 min
    If these speed/time are not met, download is terminated and restarted for a total of 3 tries.
  '''
  RunID_file_path = execution_dir_path + RunID + "/"
  paired, unpaired = get_ftp_links(RunID)
  layout = "Layout unknown"
  for i in range(3): #try downloading at most 3 times
    kallisto_start = time.time()
    timestamp = datetime.datetime.now()
    # Dl first 1m bytes, max time 600s, speed limit ~1gb for 30s, send stderr to RunID.log
    if layout == "Paired":
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
    else:
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $unpaired 2> $RunID'.log')
      if 'curl: (78)' not in open(RunID + '.log','r').read():
        if 'denied' not in open(RunID + '.log','r').read():
          layout = "Single"
      else:
        # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
        if 'curl: (78)' in open(RunID + '.log','r').read():
          size = dlsize(RunID)
          # !cp $RunID".log" $RunID"_copycurl78.log"
          # !rm $RunID".log"
          print(RunID + '[i=' + str(i) + ']: File not found. Download aborted.')
          layout = "N/A"
          status = "File not found"
          kallisto_end = time.time()
          break
        layout = "Paired"
    kallisto_end = time.time()

    #check for stderr logs, if absent, first 1GB file download is complete
    size = dlsize(RunID)
    if 'curl: (28)' not in open(RunID + '.log','r').read(): #if no slow dl speed error, acccept 
      # !cp $RunID".log" $RunID"_copy.log"
      # !rm $RunID".log"
      status = "Downloaded"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is acceptable.')
      break
    
    if RunID + '.log' in os.listdir(execution_dir_path): #remove stderr log file before contining to the next attempt of download
      # !cp $RunID".log" $RunID"_copycurl28.log"
      # !rm $RunID".log"
      status = "Download speed/time not accepted"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is not accepted.')
  
  #If download still incomplete, use the last file saved
  kallisto_time = round(kallisto_end - kallisto_start, 4)
  
  return kallisto_time, layout, status, size, timestamp

######################################################################

def get_ListOfRunID(RunTablePath):
  with open(RunTablePath,"r") as RunTable:
    ListOfRunID = [RunID.strip().upper() for RunID in RunTable.readlines()]
  if "RUNID" in ListOfRunID[0]: #If input file has header, exclude header
    ListOfRunID = ListOfRunID[1:]
  return ListOfRunID

######################################################################

def open_download_report():
  with open(download_report_name, "r") as download_report:
    download_lines = download_report.readlines()
  download_entries = [line.strip().split("\t") for line in download_lines]

  return download_lines, download_entries

######################################################################

def get_comments_index(download_lines):
  hex_line_indices = [download_lines.index(line) for line in download_lines if "#" in line]
  started_indices = [index for index in hex_line_indices if "started" in download_lines[index]]
  completed_indices = [index for index in hex_line_indices if "completed" in download_lines[index]]

  return hex_line_indices, started_indices, completed_indices

######################################################################

def get_failed_RunID(mode_type):
  '''
  Opens Download Report;
  Collate failed RunIDs from the latest COMPLETED j loop.
  '''
  if mode_type == "A": #CALLED WHEN MOVING ON TO THE NEXT J LOOP
    started_index = -1
  elif mode_type == "B": #CALLED WHEN REDOWNLOADING (j=1 or 2) WITH MODE B
    started_index = -2
  #Need to reopen download report to compile failed RunIDs
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  
  j_head_index = started_indices[started_index] # If 1<=j<=2, then 2<=len(started_indices)<=3

  # Find failed RunIDs within last completed j loop, in chronological order
  list_of_failed_RunID = []
  for index in range(j_head_index, completed_indices[-1]):
    if index not in hex_line_indices and download_entries[index][2] == "Download speed/time not accepted":
      list_of_failed_RunID.append(download_entries[index][0])

  return list_of_failed_RunID

######################################################################


def get_j():
  '''
  Get the current j loop download was paused at.
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  j = len(completed_indices)
  return j

######################################################################

def get_RunID_start(RunID_queue):
  '''
  * CALLED ONCE WHEN REDOWNLOADING WITH MODE B ONLY *

  Checks from the bottom of Download Report upwards until the lastest #start.
  Takes the latest RunID.
  RunID_start_index will be the index of the next RunID in RunID_queue.
  If all RunID in queue completed, index will simply = to len(RunID_queue),
  will move on to next j loop
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)

  for i in range((len(download_entries) - 1), (started_indices[-1]), -1):
    if i not in hex_line_indices:
      RunID_latest = download_entries[i][0]
      break

  try:
    RunID_start_index = RunID_queue.index(RunID_latest) + 1
  except:
    RunID_start_index = 0 # len(RunID_queue) will also be 0, move on to next j loop. 
    print("No RunID_start_index generated.")

  return RunID_start_index

######################################################################

def update_download_report(to_print):
  with open(download_report_name, "a+") as download_report:
    download_report.write(to_print)

######################################################################

def json_extract(RunID_file_path):
  """(str)->(str,str,str,str,str)
  Extracts info from run_info.json
  """
  kal_json = ast.literal_eval(open(RunID_file_path + "run_info.json", "r").read())
  n_processed = str(kal_json["n_processed"])
  n_pseudoaligned = str(kal_json["n_pseudoaligned"])
  p_pseudoaligned = str(kal_json["p_pseudoaligned"])
  return n_processed, n_pseudoaligned, p_pseudoaligned

######################################################################

def abundance(RunID_file_path):
  """(str)->(str)
  Computes percentage of genes mapped
  """
  with open(RunID_file_path + "abundance.tsv", "r") as abun:
    abun.readline()
    tpmlist = [line.strip("\n").split("\t")[-1] for line in abun.readlines()]
    tpmval = [val for val in tpmlist if val != "0" and val != "-nan"]
    return str(round((len(tpmval)/len(tpmlist))*100 , 1)) + "%"

######################################################################

def download_loop(RunID_start_index, RunID_queue):
  '''
  Execute inner download_loop i=3 for all RunIDs in RunID_queue;
  Updates download report as each RunID is processed.
  '''
  for index in range(RunID_start_index, len(RunID_queue)):
    RunID = RunID_queue[index]
    print()
    print("-"*40)
    print()
    job_queue = index + 1
    total_queue = len(RunID_queue)
    print('Processing ' + str(job_queue) + "/" + str(total_queue) + ": " + RunID)

    RunID_file_path = execution_dir_path + RunID + "/"
    if os.path.exists(RunID_file_path) == False:
      os.mkdir(RunID_file_path) #Directory to store kallisto files of each RunID
    download_status = [RunID, "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A"]
    '''
    *Download Report Headers*
    Run ID | Library Layout | Status | File size | Timestamp | Kallisto time(s) | n_processed | n_pseudoaligned | p_pseudoaligned | %genes mapped

    *Possible output for "Method"*
    download_status[2]
      "N/A" -> No streaming attempted yet
      "Downloaded" -> Successfully streamed and quantify single/paired-end data
      "File not found" -> FASTQ file not found on server
      "Download speed/time not accepted" -> Failed to stream at a satisfactory speed
    '''
    #Streaming method
    kallisto_time, layout, status, size, timestamp = kallisto_stream(RunID)
    if os.path.exists(RunID_file_path + "run_info.json"):
      download_status[1] = layout
      download_status[2] = status
      download_status[3] = size
      download_status[4] = str(timestamp)
      download_status[5] = str(kallisto_time)
      n_processed, n_pseudoaligned, p_pseudoaligned = json_extract(RunID_file_path)
      download_status[6] = n_processed
      download_status[7] = n_pseudoaligned
      download_status[8] = p_pseudoaligned
      download_status[9] = abundance(RunID_file_path)

    else:
      print(RunID + ": Missing kallisto output")

    update_download_report("\t".join(download_status) + "\n")

  return True

######################################################################

def stringS(col, val):
  collist = [7, 12, 10,16]
  length = collist[col] - len(str(val))
  return int(length/2)*" "+str(val)+round(length/2)*" "+"|"

######################################################################
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.2 Updating list of RunIDs to be downloaded</html>
ListOfRunID = get_ListOfRunID(RunTablePath)

# Specify variables for mode A or B

if download_mode == "A":
  j, RunID_start_index = 0, 0
  RunID_queue = ListOfRunID

elif download_mode == "B":
  j = get_j()

  if j == 3:
    RunID_queue = [] #End download. j loop completed thrice.
  else:
    if j == 0:
      RunID_queue = ListOfRunID
    elif 1 <= j <= 2:
      RunID_queue = get_failed_RunID(download_mode)
    if RunID_queue == []: # End j loop if no more failed RunID.
      j = 3
  
  RunID_start_index = get_RunID_start(RunID_queue)
  update_download_report("#Download resumed\n")

# %%
#@markdown 1.6 Loop to download experiments according to updated list of runIDs

# Loop through j x i times down the RunID_queue

for loop in range(j,3):
  print("\n" + "-"*40 + "\n")
  if RunID_start_index == 0:
    print("Download attempt %s"%(loop+1))
    update_download_report("#Download attempt %s started\n" % (loop+1))
  else:
    print("Download attempt %s resumed"%(j+1))
  
  download_loop(RunID_start_index, RunID_queue)
  update_download_report("#Download attempt %s completed\n" % (loop+1))

  #Reset RunID_start_index and RunID_queue
  RunID_start_index = 0
  RunID_queue = get_failed_RunID("A")
  if RunID_queue == []: # End j loop if no more failed RunID.
      print("All RunIDs have been successfully downloaded.")
      break
print("Download complete.")
with open(download_report_name, "r") as download_report:
  file_content = download_report.read()
  file_error = [(a.start(),a.end()) for a in list(re.finditer('File not found', file_content))]
  file_success = [(a.start(),a.end()) for a in list(re.finditer('Downloaded', file_content))]
  print("| Total | Downloaded | Rejected | File not found |\n|"\
        + stringS(0,len(get_ListOfRunID(RunTablePath)))\
        + stringS(1,len(file_success))\
        + stringS(2,len(get_ListOfRunID(RunTablePath))-len(file_success)-len(file_error))\
        + stringS(3,len(file_error)))
# Out:
# ----------------------------------------
#
# Download attempt 1 resumed
#
# ----------------------------------------
#
# Processing 299/1060: ERR850841
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2746000 @  0x7f32c2e331e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f32c1e4fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1fd0000 @  0x7f26a7afb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f26a6b17b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,659,651 reads, 8,532,127 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 456 rounds
#
# ERR850841[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 300/1060: ERR850842
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3230000 @  0x7f1bbe63d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1bbd659b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x30c4000 @  0x7fef37ad21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fef36aeeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 2,900,957 reads, 2,146,699 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 278 rounds
#
# ERR850842[i=0]: Download speed/time is not accepted.
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3276000 @  0x7f8727a6e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8726a8ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,626,253 reads, 8,607,074 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 440 rounds
#
# ERR850842[i=1]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 301/1060: ERR850843
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a72000 @  0x7f249e9a81e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f249d9c4b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2a46000 @  0x7fe71eb751e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe71db91b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,667,831 reads, 8,549,840 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 440 rounds
#
# ERR850843[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 302/1060: ERR850844
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f2c000 @  0x7f9a019da1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9a009f6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x30b8000 @  0x7f29b65821e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f29b559eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,719,771 reads, 8,563,003 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 394 rounds
#
# ERR850844[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 303/1060: SRR6471178
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2bc6000 @  0x7f7bcff0c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7bcef28b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2d2c000 @  0x7f24123521e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f241136eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,216,705 reads, 8,967,734 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 440 rounds
#
# SRR6471178[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 304/1060: SRR6471179
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17f6000 @  0x7f1ded7aa1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1dec7c6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1bb4000 @  0x7fbe543821e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fbe5339eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,220,692 reads, 8,999,770 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 383 rounds
#
# SRR6471179[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 305/1060: SRR6471180
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1476000 @  0x7efcb4d101e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7efcb3d2cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3050000 @  0x7f1c16d311e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1c15d4db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,724,389 reads, 8,941,976 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 388 rounds
#
# SRR6471180[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 306/1060: SRR6471181
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2360000 @  0x7fdf4357f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdf4259bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x21f2000 @  0x7f61e38041e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f61e2820b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,297,003 reads, 9,072,713 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 388 rounds
#
# SRR6471181[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 307/1060: SRR6471182
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1634000 @  0x7fdc9d3221e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdc9c33eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2de8000 @  0x7fbd752751e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fbd74291b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,752,951 reads, 9,373,516 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 274 rounds
#
# SRR6471182[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 308/1060: SRR6471183
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2aba000 @  0x7ff5030a11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff5020bdb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3092000 @  0x7f2d945fe1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2d9361ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,207,739 reads, 8,902,880 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 482 rounds
#
# SRR6471183[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 309/1060: SRR6471184
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c7a000 @  0x7fedfe6e81e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fedfd704b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ba2000 @  0x7fdb103361e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdb0f352b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 9,787,216 reads, 6,833,369 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 373 rounds
#
# SRR6471184[i=0]: Download speed/time is not accepted.
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2e42000 @  0x7f2c502061e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2c4f222b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,440,547 reads, 9,383,575 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 429 rounds
#
# SRR6471184[i=1]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 310/1060: SRR6471185
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2fc0000 @  0x7f70677c71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f70667e3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3164000 @  0x7fa4a1bd11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa4a0bedb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,903,672 reads, 9,251,180 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 465 rounds
#
# SRR6471185[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 311/1060: SRR6471186
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x24dc000 @  0x7f7cbbc751e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7cbac91b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1bf8000 @  0x7fc574e0d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc573e29b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 866,450 reads, 645,056 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 413 rounds
#
# SRR6471186[i=0]: Download speed/time is not accepted.
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x22a8000 @  0x7f9df12f31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9df030fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 158,631 reads, 117,865 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 413 rounds
#
# SRR6471186[i=1]: Download speed/time is not accepted.
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2394000 @  0x7f2ce6ce01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2ce5cfcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,058,742 reads, 9,718,368 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 447 rounds
#
# SRR6471186[i=2]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 312/1060: SRR6471187
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1d4a000 @  0x7f392a5791e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3929595b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2658000 @  0x7fda1f6ea1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fda1e706b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,781,655 reads, 9,154,820 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 319 rounds
#
# SRR6471187[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 313/1060: SRR6471188
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2252000 @  0x7ff8945b61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff8935d2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1b20000 @  0x7f357d8b81e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f357c8d4b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,759,995 reads, 9,594,680 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 440 rounds
#
# SRR6471188[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 314/1060: SRR6471189
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2840000 @  0x7ffacd0f41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ffacc110b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x184e000 @  0x7fb0bbfc41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb0bafe0b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,006,261 reads, 8,386,408 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 268 rounds
#
# SRR6471189[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 315/1060: SRR6471190
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1fc8000 @  0x7f8aa06921e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8a9f6aeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x186e000 @  0x7fa69be711e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa69ae8db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,977,637 reads, 8,887,199 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 482 rounds
#
# SRR6471190[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 316/1060: SRR6471192
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2a20000 @  0x7f11480fc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1147118b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2e06000 @  0x7f08a1f2a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f08a0f46b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,881,226 reads, 9,381,460 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 482 rounds
#
# SRR6471192[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 317/1060: SRR7427350
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x21f6000 @  0x7fbda59081e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fbda4924b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1884000 @  0x7f09939361e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0992952b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,923,181 reads, 10,356,153 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 430 rounds
#
# SRR7427350[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 318/1060: SRR7427351
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1cae000 @  0x7f8aa32bd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8aa22d9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x19ca000 @  0x7fdbbfcd61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdbbecf2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,459,464 reads, 9,964,220 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 320 rounds
#
# SRR7427351[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 319/1060: SRR7427352
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x30da000 @  0x7fe28409c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe2830b8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2156000 @  0x7f62499d31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f62489efb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,867,780 reads, 9,825,605 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 503 rounds
#
# SRR7427352[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 320/1060: SRR7427353
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2d3e000 @  0x7f7cbfcfe1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7cbed1ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1e0c000 @  0x7f97846401e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f978365cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,180,343 reads, 9,773,990 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 216 rounds
#
# SRR7427353[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 321/1060: SRR7427354
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x291a000 @  0x7f4d7922a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4d78246b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2808000 @  0x7f6471b8d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6470ba9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,929,970 reads, 9,887,718 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 412 rounds
#
# SRR7427354[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 322/1060: SRR7427355
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1d7e000 @  0x7f861afc01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8619fdcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3218000 @  0x7fd9db0411e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd9da05db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,932,658 reads, 9,882,820 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 373 rounds
#
# SRR7427355[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 323/1060: SRR6364640
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x26ec000 @  0x7faffe82c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7faffd848b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x24ce000 @  0x7f9ea28ad1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9ea18c9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,290,833 reads, 11,543,380 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 580 rounds
#
# SRR6364640[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 324/1060: SRR6364641
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x31d2000 @  0x7fb4e89aa1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb4e79c6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x27e0000 @  0x7f4898e771e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4897e93b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,617,757 reads, 11,298,553 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 613 rounds
#
# SRR6364641[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 325/1060: SRR6364642
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2cbe000 @  0x7fd0a2f5f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd0a1f7bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x231a000 @  0x7fa7136421e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa71265eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,660,101 reads, 13,260,734 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 450 rounds
#
# SRR6364642[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 326/1060: SRR6364643
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2de4000 @  0x7fe47c5a41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe47b5c0b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1d52000 @  0x7ff44aa731e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff449a8fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,675,210 reads, 12,873,009 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 440 rounds
#
# SRR6364643[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 327/1060: SRR6364644
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2230000 @  0x7f754212d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7541149b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3122000 @  0x7f68947f71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6893813b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,844,226 reads, 12,147,004 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 381 rounds
#
# SRR6364644[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 328/1060: SRR6364645
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2d0a000 @  0x7f296b48e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f296a4aab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ed0000 @  0x7fd3fcc3c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd3fbc58b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 18,240,028 reads, 13,518,556 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 595 rounds
#
# SRR6364645[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 329/1060: SRR6364646
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# ...
# tcmalloc: large alloc 1610612736 bytes == 0x2280000 @  0x7fe4786e01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe4776fcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c82000 @  0x7fcfbc5d91e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fcfbb5f5b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,287,854 reads, 8,368,333 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 447 rounds
#
# SRR8568069[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 376/1060: DRR087484
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x180c000 @  0x7f6df46031e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6df361fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x180c000 @  0x7fb57fb2a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb57eb46b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 17,322,739 reads, 12,601,573 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# DRR087484[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 377/1060: DRR087485
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a72000 @  0x7f5ed66ea1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5ed5706b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3174000 @  0x7fc279df41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc278e10b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 19,829,007 reads, 11,683,899 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 291 rounds
#
# DRR087485[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 378/1060: DRR087486
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2884000 @  0x7f01952771e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0194293b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2062000 @  0x7fe5941f01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe59320cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 19,800,577 reads, 12,828,511 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 606 rounds
#
# DRR087486[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 379/1060: DRR087487
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3022000 @  0x7ff9cf9d71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff9ce9f3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1bd8000 @  0x7f701a1ea1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7019206b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 20,421,578 reads, 12,038,018 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 539 rounds
#
# DRR087487[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 380/1060: SRR8096935
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2faa000 @  0x7f6da28281e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6da1844b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,466,176 reads, 16,778,558 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# SRR8096935[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 381/1060: SRR8096936
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2648000 @  0x7f496ba0f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f496aa2bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,317,391 reads, 16,793,314 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# SRR8096936[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 382/1060: SRR8096938
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2434000 @  0x7f0aeb6d01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0aea6ecb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 25,137,633 reads, 16,909,034 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 521 rounds
#
# SRR8096938[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 383/1060: SRR6434919
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1bcc000 @  0x7fa21739d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa2163b9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,220,662 reads, 8,078,917 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 595 rounds
#
# SRR6434919[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 384/1060: SRR6434924
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ede000 @  0x7f7bbea081e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7bbda24b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 16,108,049 reads, 11,282,416 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 749 rounds
#
# SRR6434924[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 385/1060: SRR6434926
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3290000 @  0x7eff03f541e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7eff02f70b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,523,144 reads, 7,370,793 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 694 rounds
#
# SRR6434926[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 386/1060: SRR6434932
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x216a000 @  0x7efd9e3bc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7efd9d3d8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,842,067 reads, 9,113,968 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 595 rounds
#
# SRR6434932[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 387/1060: SRR6434938
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2bc4000 @  0x7f74088521e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f740786eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,579,319 reads, 10,018,761 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 434 rounds
#
# SRR6434938[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 388/1060: SRR6434949
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x130e000 @  0x7f91a6f001e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f91a5f1cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 21,077,496 reads, 14,727,249 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 712 rounds
#
# SRR6434949[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 389/1060: SRR6434950
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17c0000 @  0x7f922b9ad1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f922a9c9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 20,922,953 reads, 14,790,642 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 330 rounds
#
# SRR6434950[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 390/1060: SRR6434953
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1b80000 @  0x7f997a51c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9979538b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 18,945,747 reads, 12,905,992 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 652 rounds
