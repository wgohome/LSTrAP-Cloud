# %% [markdown]
# <a href="https://colab.research.google.com/github/tqiaowen/LSTrAP-Cloud/blob/master/mod_download_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Downloading FASTQ files from ENA
# This script is based on the original download script found [here](https://github.com/wirriamm/CoNeGC/blob/master/1_Download_scripts_30Jan.ipynb), obtained on 30 January 2020.
#
# ### What does this script do?
# This script will help you stream RNA-seq data (FASTQ files) from ENA and quantify the RNA transcript abundance using kallisto concurrently.
#
# ### What you will require
# 1. A Google Account to save your data
# 2. A folder in your Google Drive containing<br>
#   a) RunTable file<br>This file should contain the list of RunIDs that you want to download from ENA ([example]())<br>
#   b) CDS file of the organism that you are interested to work with
#
# ### Expected outputs
# 1. Kallisto index of your organism's CDS<br>
# 2. Kallisto output folders<br>
# 3. Download report<br>Summarises for each RunID the status of download, amount of data downloaded, amount of time taken for kallisto streaming and a statistics from kallisto
#
#
# ### Bonus tips?
# 1. If you noticed that the file has not been downloaded successfully ("Download speed/time not accepted"), not to worry, the script will attempt to download it again.
# 2. Download got interrupted due to runtime disconnecting? Just re-run the script with 'Option B' (Step 1.2, part 5) and specify the date when you started the download.
# 3. If you encoutner any issues, please raise an issue on [Github](https://github.com/tqiaowen/LSTrAP-Cloud) or contact us [here](mailto:qiaowen001@e.ntu.edu.sg).

# %%
#@markdown ####1.1 Mount Google Drive and import python modules

#Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# !rm -rf /content/sample_data

#Import modules
import os
import time
from datetime import datetime as dt
import scipy.stats as stats
import json
import math
import re
import ast
import datetime
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ####User input of variables

# %%
#@title 1.2 Input form {display-mode: "form"}

#@markdown 1) Enter the absolute path for the folder you are going to work with. Tip: After mounting your Google Drive, right click on the file and copy path.<br>
#@markdown <html><img src = 'https://github.com/tqiaowen/LSTrAP-Cloud/blob/master/img/folder_path.png?raw=true', alt = 'Copy file path' width=360 height=287></html>

in_dir = '/content/gdrive/My Drive/Projects/William_2019/Nta_Edward' #@param {type: 'string'}

#@markdown ---

#@markdown 2) Enter the species name. Eg. _Nicotiana tabacum_ can be shortened to **Nta**

species_name = 'Nta' #@param {type: 'string'}

#@markdown ---

#@markdown 3) File name for Run Table (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**runid_Nta.txt**_'

RunTable_file = 'runid_Nta.txt' #@param {type: 'string'}

#@markdown ---

#@markdown 4) File name for CDS file (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**GCF_000715135.1_Ntab-TN90_cds_from_genomic.fna.gz**_'

cds_fasta_file = 'Nitab-v4.5_cDNA_Edwards2017.fasta' #@param {type: 'string'}

#@markdown ---

#@markdown 5) Specify download mode

download_mode = "B. Continue from previous run" #@param ["A. Start fresh run", "B. Continue from previous run"]
download_mode = download_mode[0]

if download_mode == "B":
  Date_initiated = '2020-02-14' #@param {type: 'date'}
  date = Date_initiated

# %%
#@markdown 1.3 Install Dependencies, Initialise Variables and Directories

#Create Dependencies directory
if os.path.exists('/content/Dependencies') == False:
  os.mkdir('/content/Dependencies')
  os.chdir('/content/Dependencies')
  print('Dependencies directory created.')
  #Download and install kallisto
  os.system('wget \'https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz\'')
  os.system('tar -xf kallisto_linux-v0.46.0.tar.gz')
  if os.path.exists('kallisto/kallisto'):
    print('kallisto installed.')
    # !cp kallisto/kallisto /bin/kallisto
  else:
    print('kallisto not found.')

#Define paths
working_dir_path = "/content/gdrive/My Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
working_dir_path_ter = "/content/gdrive/My\ Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
  #Note: "\(whitespace)" is needed when we are calling shell command as a string via os.system
RunTablePath = working_dir_path + RunTable_file
cds_fasta_path = working_dir_path_ter + cds_fasta_file    

#Make new directory for this execution of the script if user chooses option "A"
os.chdir(working_dir_path)

if download_mode == "A":
  date = str(dt.now().date())
  files = os.listdir(working_dir_path)
  try:
      os.mkdir(working_dir_path + date + "_01")
      print(date + "_01 directory has been created.") 
  except FileExistsError:
      filename = max([filename for filename in files if date in filename])
      file_serial_int = int(filename[-2:]) + 1
      if 1 < file_serial_int < 10:
          file_serial_str = "0" + str(file_serial_int)
      elif 10 <= file_serial_int < 100:
          file_serial_str = str(file_serial_int)
          
      os.mkdir(working_dir_path + date + "_" + file_serial_str)
      print(date + "_" + file_serial_str + " directory has been created.")
  except:
      print("Directory failed to be created.")

#Calls the most recent directory
#Will start from here for Option "B"
files = os.listdir(working_dir_path)
filename = max([filename for filename in files if date in filename])
execution_dir_path = working_dir_path + filename + "/"
execution_dir_path_ter = working_dir_path_ter + filename + "/"

#Download report
#Create a tab-separated .txt logfile that stores time and progress in this workflow
os.chdir(execution_dir_path)
#species_name = (RunTablePath.split('/')[-1]).split('_',1)[1][:-4]
download_report_name = "Download_report_" + species_name + "_" + date + ".txt"

if os.path.exists(download_report_name):
  pass
  #For Option B, Download report will be read later in the for loop

else:
  #Create new download report
  download_report = open(download_report_name, "a+")
  download_report.write("Run ID\tLibrary Layout\tStatus\tFile size\tTimestamp\tKallisto time (s)\tn_processed\tn_pseudoaligned\tp_pseudoaligned\t%genes mapped\n")
  download_report.close()
# Out:
# Dependencies directory created.
# kallisto installed.

# %%
#@markdown 1.4 Create kallisto index
kallisto_index_path_ter = execution_dir_path_ter + "index_file_" + species_name #to be created by kallisto
kallisto_index_path = execution_dir_path + "index_file_" + species_name

if os.path.exists(kallisto_index_path):
  print("Kallisto index already present for " + species_name + ".")
else:
  index_start = time.time()
  # os.system(kallisto_path + " index -i " + kallisto_index_path_ter + " " + cds_fasta_path)
  # !kallisto index -i $kallisto_index_path_ter $cds_fasta_path
  if os.path.exists(kallisto_index_path):
    print("Kallisto index created for " + species_name + ".")
    print("Time to create kallisto index:", time.time()-index_start)
  else:
    print("Kallisto index not found for " + species_name + ".")
# Out:
# Kallisto index already present for Nta.

# %%
#@markdown 1.5 Preparation for download<br>
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.1 Initialise download functions</html>
#Functions#############################################################

def get_ftp_links(RunID):
  '''(str)->(str,str)
  Return ftp link in the paired and unpaired format for the RunID specified
  '''
  dir2 = ""
  if 9 < len(RunID) <= 12:
      dir2 = "0"*(12 - len(RunID)) + RunID[-(len(RunID)-9):] + "/"
  dirs = RunID[:6] + "/" + dir2 + RunID
  ftp_link_paired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + "_1.fastq.gz"
  ftp_link_unpaired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + ".fastq.gz"
  return ftp_link_paired, ftp_link_unpaired

######################################################################

def dlsize(RunID, num):
  """(str)->(str)
  Returns size of downloaded file obtained from the log
  """
  ll= open(RunID +".log", "r").readlines()[num].split(" ")
  con = []
  for i in ll:
    if i != '':
      con.append(i)
    if len(con) >= 4:
      break
  return con[-1]

######################################################################

def kallisto_stream(RunID):
  '''(str)->(float,str,str,str,str)
  Runs kallisto quant on streamed fastq file for each RunID, streaming the unpaired file first. If streaming for unpaired file fails, streaming will be attempted for paired file.
  If both streaming for unpaired and paired files are unsuccessful, i.e. curl: (78) RETR response: 550; file probably does not exist on server and subsequent attempts will be aborted.
  For streaming (curl command):
    Streams only the first 1M bytes of data.
    Ensures that:
      Download speed not < 1x10^9 Bytes for 30 s
      Maximum time taken = 600 s = 10 min
    If these speed/time are not met, download is terminated and restarted for a total of 3 tries.
  '''
  RunID_file_path = execution_dir_path + RunID + "/"
  paired, unpaired = get_ftp_links(RunID)
  layout = "Layout unknown"
  for i in range(3): #try downloading at most 3 times
    kallisto_start = time.time()
    timestamp = datetime.datetime.now()
    # Dl first 1m bytes, max time 600s, speed limit ~1gb for 30s, send stderr to RunID.log
    if layout == "Paired":
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
    else:
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $unpaired 2> $RunID'.log')
      if 'curl: (78)' not in open(RunID + '.log','r').read():
        if 'curl: (9)' not in open(RunID + '.log','r').read():
          layout = "Single"
        elif 'curl: (9)' in open(RunID + '.log','r').read():
          size = dlsize(RunID, -2)
          # !cp $RunID".log" $RunID"_copycurl9.log"
          # !rm $RunID".log"
          print(RunID + '[i=' + str(i) + ']: File not found. Download aborted.')
          layout = "N/A"
          status = "File not found"
          kallisto_end = time.time()
          break
      else:
        # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
        if 'curl: (78)' in open(RunID + '.log','r').read():
          size = dlsize(RunID, -2)
          # !cp $RunID".log" $RunID"_copycurl78.log"
          # !rm $RunID".log"
          print(RunID + '[i=' + str(i) + ']: File not found. Download aborted.')
          layout = "N/A"
          status = "File not found"
          kallisto_end = time.time()
          break
        layout = "Paired"
    kallisto_end = time.time()

    #check for stderr logs, if absent, first 1GB file download is complete
    
    if 'curl: (28)' not in open(RunID + '.log','r').read(): #if no slow dl speed error, acccept 
      size = dlsize(RunID, -1)
      # !cp $RunID".log" $RunID"_copy.log"
      # !rm $RunID".log"
      status = "Downloaded"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is acceptable.')
      break
    
    if RunID + '.log' in os.listdir(execution_dir_path): #remove stderr log file before contining to the next attempt of download
      size = dlsize(RunID, -2)
      # !cp $RunID".log" $RunID"_copycurl28.log"
      # !rm $RunID".log"
      status = "Download speed/time not accepted"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is not accepted.')
  
  #If download still incomplete, use the last file saved
  kallisto_time = round(kallisto_end - kallisto_start, 4)
  
  return kallisto_time, layout, status, size, timestamp

######################################################################

def get_ListOfRunID(RunTablePath):
  with open(RunTablePath,"r") as RunTable:
    ListOfRunID = [RunID.strip().upper() for RunID in RunTable.readlines()]
  if "RUNID" in ListOfRunID[0]: #If input file has header, exclude header
    ListOfRunID = ListOfRunID[1:]
  return ListOfRunID

######################################################################

def open_download_report():
  with open(download_report_name, "r") as download_report:
    download_lines = download_report.readlines()
  download_entries = [line.strip().split("\t") for line in download_lines]

  return download_lines, download_entries

######################################################################

def get_comments_index(download_lines):
  hex_line_indices = [download_lines.index(line) for line in download_lines if "#" in line]
  started_indices = [index for index in hex_line_indices if "started" in download_lines[index]]
  completed_indices = [index for index in hex_line_indices if "completed" in download_lines[index]]

  return hex_line_indices, started_indices, completed_indices

######################################################################

def get_failed_RunID(mode_type):
  '''
  Opens Download Report;
  Collate failed RunIDs from the latest COMPLETED j loop.
  '''
  if mode_type == "A": #CALLED WHEN MOVING ON TO THE NEXT J LOOP
    started_index = -1
  elif mode_type == "B": #CALLED WHEN REDOWNLOADING (j=1 or 2) WITH MODE B
    started_index = -2
  #Need to reopen download report to compile failed RunIDs
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  
  j_head_index = started_indices[started_index] # If 1<=j<=2, then 2<=len(started_indices)<=3

  # Find failed RunIDs within last completed j loop, in chronological order
  list_of_failed_RunID = []
  for index in range(j_head_index, completed_indices[-1]):
    if index not in hex_line_indices and download_entries[index][2] == "Download speed/time not accepted":
      list_of_failed_RunID.append(download_entries[index][0])

  return list_of_failed_RunID

######################################################################


def get_j():
  '''
  Get the current j loop download was paused at.
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  j = len(completed_indices)
  return j

######################################################################

def get_RunID_start(RunID_queue):
  '''
  * CALLED ONCE WHEN REDOWNLOADING WITH MODE B ONLY *

  Checks from the bottom of Download Report upwards until the lastest #start.
  Takes the latest RunID.
  RunID_start_index will be the index of the next RunID in RunID_queue.
  If all RunID in queue completed, index will simply = to len(RunID_queue),
  will move on to next j loop
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)

  for i in range((len(download_entries) - 1), (started_indices[-1]), -1):
    if i not in hex_line_indices:
      RunID_latest = download_entries[i][0]
      break

  try:
    RunID_start_index = RunID_queue.index(RunID_latest) + 1
  except:
    RunID_start_index = 0 # len(RunID_queue) will also be 0, move on to next j loop. 
    print("No RunID_start_index generated.")

  return RunID_start_index

######################################################################

def update_download_report(to_print):
  with open(download_report_name, "a+") as download_report:
    download_report.write(to_print)

######################################################################

def json_extract(RunID_file_path):
  """(str)->(str,str,str,str,str)
  Extracts info from run_info.json
  """
  kal_json = ast.literal_eval(open(RunID_file_path + "run_info.json", "r").read())
  n_processed = str(kal_json["n_processed"])
  n_pseudoaligned = str(kal_json["n_pseudoaligned"])
  p_pseudoaligned = str(kal_json["p_pseudoaligned"])
  return n_processed, n_pseudoaligned, p_pseudoaligned

######################################################################

def abundance(RunID_file_path):
  """(str)->(str)
  Computes percentage of genes mapped
  """
  with open(RunID_file_path + "abundance.tsv", "r") as abun:
    abun.readline()
    tpmlist = [line.strip("\n").split("\t")[-1] for line in abun.readlines()]
    tpmval = [val for val in tpmlist if val != "0" and val != "-nan"]
    return str(round((len(tpmval)/len(tpmlist))*100 , 1)) + "%"

######################################################################

def download_loop(RunID_start_index, RunID_queue):
  '''
  Execute inner download_loop i=3 for all RunIDs in RunID_queue;
  Updates download report as each RunID is processed.
  '''
  for index in range(RunID_start_index, len(RunID_queue)):
    RunID = RunID_queue[index]
    print()
    print("-"*40)
    print()
    job_queue = index + 1
    total_queue = len(RunID_queue)
    print('Processing ' + str(job_queue) + "/" + str(total_queue) + ": " + RunID)

    RunID_file_path = execution_dir_path + RunID + "/"
    if os.path.exists(RunID_file_path) == False:
      os.mkdir(RunID_file_path) #Directory to store kallisto files of each RunID
    download_status = [RunID, "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A"]
    '''
    *Download Report Headers*
    Run ID | Library Layout | Status | File size | Timestamp | Kallisto time(s) | n_processed | n_pseudoaligned | p_pseudoaligned | %genes mapped

    *Possible output for "Method"*
    download_status[2]
      "N/A" -> No streaming attempted yet
      "Downloaded" -> Successfully streamed and quantify single/paired-end data
      "File not found" -> FASTQ file not found on server
      "Download speed/time not accepted" -> Failed to stream at a satisfactory speed
    '''
    #Streaming method
    kallisto_time, layout, status, size, timestamp = kallisto_stream(RunID)
    if os.path.exists(RunID_file_path + "run_info.json"):
      download_status[1] = layout
      download_status[2] = status
      download_status[3] = size
      download_status[4] = str(timestamp)
      download_status[5] = str(kallisto_time)
      n_processed, n_pseudoaligned, p_pseudoaligned = json_extract(RunID_file_path)
      download_status[6] = n_processed
      download_status[7] = n_pseudoaligned
      download_status[8] = p_pseudoaligned
      download_status[9] = abundance(RunID_file_path)

    else:
      print(RunID + ": Missing kallisto output")

    update_download_report("\t".join(download_status) + "\n")

  return True

######################################################################

def stringS(col, val):
  collist = [7, 12, 10,16]
  length = collist[col] - len(str(val))
  return int(length/2)*" "+str(val)+round(length/2)*" "+"|"

######################################################################
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.2 Updating list of RunIDs to be downloaded</html>
ListOfRunID = get_ListOfRunID(RunTablePath)

# Specify variables for mode A or B

if download_mode == "A":
  j, RunID_start_index = 0, 0
  RunID_queue = ListOfRunID

elif download_mode == "B":
  j = get_j()

  if j == 3:
    RunID_queue = [] #End download. j loop completed thrice.
  else:
    if j == 0:
      RunID_queue = ListOfRunID
    elif 1 <= j <= 2:
      RunID_queue = get_failed_RunID(download_mode)
    if RunID_queue == []: # End j loop if no more failed RunID.
      j = 3
  
  RunID_start_index = get_RunID_start(RunID_queue)
  update_download_report("#Download resumed\n")

# %%
#@markdown 1.6 Loop to download experiments according to updated list of runIDs

# Loop through j x i times down the RunID_queue

for loop in range(j,3):
  print("\n" + "-"*40 + "\n")
  if RunID_start_index == 0:
    print("Download attempt %s"%(loop+1))
    update_download_report("#Download attempt %s started\n" % (loop+1))
  else:
    print("Download attempt %s resumed"%(j+1))
  
  download_loop(RunID_start_index, RunID_queue)
  update_download_report("#Download attempt %s completed\n" % (loop+1))

  #Reset RunID_start_index and RunID_queue
  RunID_start_index = 0
  RunID_queue = get_failed_RunID("A")
  if RunID_queue == []: # End j loop if no more failed RunID.
      print("All RunIDs have been successfully downloaded.")
      break
print("Download complete.")
with open(download_report_name, "r") as download_report:
  file_content = download_report.read()
  file_error = [(a.start(),a.end()) for a in list(re.finditer('File not found', file_content))]
  file_success = [(a.start(),a.end()) for a in list(re.finditer('Downloaded', file_content))]
  print("| Total | Downloaded | Rejected | File not found |\n|"\
        + stringS(0,len(get_ListOfRunID(RunTablePath)))\
        + stringS(1,len(file_success))\
        + stringS(2,len(get_ListOfRunID(RunTablePath))-len(file_success)-len(file_error))\
        + stringS(3,len(file_error)))
# Out:
# ----------------------------------------
#
# Download attempt 1 resumed
#
# ----------------------------------------
#
# Processing 841/1060: SRR10714429
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2aa0000 @  0x7fe1389c11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe1379ddb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1c32000 @  0x7fe18076f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe17f78bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,396,157 reads, 10,183,758 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 284 rounds
#
# SRR10714429[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 842/1060: SRR10716746
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1896000 @  0x7fe59463a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe593656b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x31b6000 @  0x7f1f1469a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1f136b6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,710,752 reads, 10,760,683 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 565 rounds
#
# SRR10716746[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 843/1060: SRR10716747
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x296a000 @  0x7f07605061e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f075f522b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2352000 @  0x7f9392a091e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9391a25b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,660,641 reads, 10,641,361 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 531 rounds
#
# SRR10716747[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 844/1060: SRR10716748
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2cbe000 @  0x7fea711db1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fea701f7b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3070000 @  0x7fb25045a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb24f476b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 14,315,907 reads, 10,249,844 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 592 rounds
#
# SRR10716748[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 845/1060: SRR10030315
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3066000 @  0x7fcf8fee31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fcf8eeffb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x25ce000 @  0x7f1ea9ead1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1ea8ec9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,818,812 reads, 7,013,588 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 388 rounds
#
# SRR10030315[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 846/1060: SRR10030316
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x284e000 @  0x7f113d5fc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f113c618b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x21ae000 @  0x7f11ae1ac1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f11ad1c8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,536,545 reads, 7,762,920 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 436 rounds
#
# SRR10030316[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 847/1060: SRR7850934
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1694000 @  0x7f4ddcab91e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4ddbad5b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x21d4000 @  0x7fc9cee151e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc9cde31b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,960,055 reads, 9,517,560 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 476 rounds
#
# SRR7850934[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 848/1060: SRR7850935
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c1c000 @  0x7f1c770f11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1c7610db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x298c000 @  0x7f05964cb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f05954e7b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,820,496 reads, 9,572,750 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 351 rounds
#
# SRR7850935[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 849/1060: SRR7850936
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1336000 @  0x7fd57a18f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd5791abb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x13f4000 @  0x7fa8964711e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa89548db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,014,233 reads, 9,657,843 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 183 rounds
#
# SRR7850936[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 850/1060: SRR7850937
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x12e8000 @  0x7f91b6c1c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f91b5c38b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x22fe000 @  0x7f6624cc51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6623ce1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,922,083 reads, 9,822,296 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 355 rounds
#
# SRR7850937[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 851/1060: SRR7850938
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x25a4000 @  0x7f843d7cc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f843c7e8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2fdc000 @  0x7efd22e691e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7efd21e85b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,854,777 reads, 9,521,849 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 482 rounds
#
# SRR7850938[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 852/1060: SRR7850939
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f26000 @  0x7fe6206f51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe61f711b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x21cc000 @  0x7fc48227a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc481296b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,863,148 reads, 9,495,945 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 462 rounds
#
# SRR7850939[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 853/1060: SRR7850940
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1bba000 @  0x7f31028bb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f31018d7b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c0e000 @  0x7f61262aa1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f61252c6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,864,389 reads, 9,944,336 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 333 rounds
#
# SRR7850940[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 854/1060: SRR7850941
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1e72000 @  0x7fc707da51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc706dc1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x31c6000 @  0x7f325eff11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f325e00db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,809,386 reads, 9,818,637 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 462 rounds
#
# SRR7850941[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 855/1060: SRR7850942
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c96000 @  0x7f587d83f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f587c85bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f2c000 @  0x7f82d9e671e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f82d8e83b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,939,292 reads, 9,954,838 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 502 rounds
#
# SRR7850942[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 856/1060: SRR7850943
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1480000 @  0x7f3fbfbd11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3fbebedb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2966000 @  0x7f90f030c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f90ef328b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,771,397 reads, 9,634,756 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 326 rounds
#
# SRR7850943[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 857/1060: SRR7850944
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17ae000 @  0x7f60122dc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f60112f8b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2318000 @  0x7f2936ed61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2935ef2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,033,959 reads, 9,842,162 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 462 rounds
#
# SRR7850944[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 858/1060: SRR7850945
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1e8a000 @  0x7f1238b691e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1237b85b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1736000 @  0x7f0a835ad1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0a825c9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,006,811 reads, 9,519,414 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 525 rounds
#
# SRR7850945[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 859/1060: SRR7850946
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f10000 @  0x7f9fc8efc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9fc7f18b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2efe000 @  0x7fa1f6b601e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa1f5b7cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,794,871 reads, 9,615,753 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 419 rounds
#
# SRR7850946[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 860/1060: SRR7850947
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2116000 @  0x7f89d8c1c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f89d7c38b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2188000 @  0x7fc3848e61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc383902b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,882,791 reads, 8,053,563 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 510 rounds
#
# SRR7850947[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 861/1060: SRR7850948
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x12f2000 @  0x7f827e1c51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f827d1e1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x19f4000 @  0x7fb7f5a201e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb7f4a3cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,750,701 reads, 9,255,041 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 447 rounds
#
# SRR7850948[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 862/1060: SRR7850949
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1b50000 @  0x7fc92d04c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc92c068b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3140000 @  0x7f9263cc31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9262cdfb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,819,755 reads, 9,554,510 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 473 rounds
#
# SRR7850949[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 863/1060: SRR7850950
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x270a000 @  0x7f03221a21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f03211beb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c78000 @  0x7f715dc441e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f715cc60b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,899,571 reads, 9,595,392 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 507 rounds
#
# SRR7850950[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 864/1060: SRR7850951
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ef2000 @  0x7f9eaa5751e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9ea9591b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3164000 @  0x7f800ea681e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f800da84b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,996,985 reads, 9,096,250 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 388 rounds
#
# SRR7850951[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 865/1060: SRR7850952
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x18fc000 @  0x7f838b2501e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f838a26cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1abe000 @  0x7f92d8a891e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f92d7aa5b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,981,923 reads, 9,593,101 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 482 rounds
#
# SRR7850952[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 866/1060: SRR7850953
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1c3e000 @  0x7f9ba65f71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9ba5613b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1d42000 @  0x7f2fc32631e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2fc227fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 13,156,464 reads, 9,744,015 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 447 rounds
#
# SRR7850953[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 867/1060: SRR7850954
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x29ca000 @  0x7ff83507c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff834098b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x311a000 @  0x7fea0b5721e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fea0a58eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,875,078 reads, 9,455,057 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 503 rounds
#
# SRR7850954[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 868/1060: SRR7850955
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ffc000 @  0x7fd02ee4d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd02de69b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1b10000 @  0x7fc45761d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc456639b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,936,906 reads, 9,373,551 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 429 rounds
#
# SRR7850955[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 869/1060: SRR7850956
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2ff8000 @  0x7fb3556561e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb354672b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2066000 @  0x7f2da16be1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2da06dab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,944,066 reads, 9,386,379 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 560 rounds
#
# SRR7850956[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 870/1060: SRR7850957
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f0e000 @  0x7feb4c7dd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7feb4b7f9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2082000 @  0x7f2eb5b2a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2eb4b46b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,986,040 reads, 9,610,851 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 447 rounds
#
# SRR7850957[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 871/1060: SRR7850958
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3098000 @  0x7f8be34b31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8be24cfb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x16f6000 @  0x7f4d2adb51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4d29dd1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,983,234 reads, 9,346,575 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 422 rounds
#
# SRR7850958[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 872/1060: SRR7850959
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2d46000 @  0x7fe110ef91e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe10ff15b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a28000 @  0x7f12d3b6f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f12d2b8bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,920,631 reads, 9,744,196 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 360 rounds
#
# SRR7850959[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 873/1060: SRR7850960
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# ...
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,661,770 reads, 7,358,645 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 233 rounds
#
# SRR6002829[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 966/1060: SRR6002830
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2a80000 @  0x7f4d88e081e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4d87e24b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c18000 @  0x7f48dfe5d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f48dee79b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,564,582 reads, 7,919,051 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 323 rounds
#
# SRR6002830[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 967/1060: SRR6002831
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x142c000 @  0x7f90c528f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f90c42abb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2a40000 @  0x7ff8ec7a11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff8eb7bdb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,963,311 reads, 6,870,471 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 478 rounds
#
# SRR6002831[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 968/1060: SRR6002832
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ee0000 @  0x7fee17a8e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fee16aaab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1318000 @  0x7fc0718fd1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc070919b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,297,238 reads, 6,447,420 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 437 rounds
#
# SRR6002832[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 969/1060: SRR6002833
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x183e000 @  0x7fe4cda6e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe4cca8ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x32a6000 @  0x7f3baf4421e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3bae45eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,442,353 reads, 7,811,467 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 381 rounds
#
# SRR6002833[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 970/1060: SRR6002834
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1364000 @  0x7f9deaac31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9de9adfb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2220000 @  0x7f06f8b9e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f06f7bbab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,786,890 reads, 6,653,650 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 650 rounds
#
# SRR6002834[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 971/1060: SRR6002835
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2050000 @  0x7f61a321f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f61a223bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x190a000 @  0x7f55efa2a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f55eea46b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,747,652 reads, 6,191,460 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 373 rounds
#
# SRR6002835[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 972/1060: SRR6002836
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20b6000 @  0x7f95e2b051e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f95e1b21b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2eb8000 @  0x7f80baebf1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f80b9edbb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,687,304 reads, 5,806,546 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 405 rounds
#
# SRR6002836[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 973/1060: SRR6002837
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2a94000 @  0x7fab247421e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fab2375eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x213c000 @  0x7f60d42a01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f60d32bcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,744,558 reads, 7,313,795 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 600 rounds
#
# SRR6002837[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 974/1060: SRR6002838
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x13de000 @  0x7f70838c01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f70828dcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1c96000 @  0x7efcef8bf1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7efcee8dbb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,907,618 reads, 5,547,028 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 417 rounds
#
# SRR6002838[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 975/1060: SRR6002839
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1f14000 @  0x7f4e661de1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4e651fab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2bfe000 @  0x7f3127c981e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3126cb4b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,772,734 reads, 6,379,546 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 538 rounds
#
# SRR6002839[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 976/1060: SRR8934910
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x28dc000 @  0x7f0b8b4991e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0b8a4b5b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
