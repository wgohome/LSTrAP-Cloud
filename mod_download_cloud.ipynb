# %% [markdown]
# <a href="https://colab.research.google.com/github/tqiaowen/LSTrAP-Cloud/blob/master/mod_download_cloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Downloading FASTQ files from ENA
# This script is based on the original download script found [here](https://github.com/wirriamm/CoNeGC/blob/master/1_Download_scripts_30Jan.ipynb), obtained on 30 January 2020.
#
# ### What does this script do?
# This script will help you stream RNA-seq data (FASTQ files) from ENA and quantify the RNA transcript abundance using kallisto concurrently.
#
# ### What you will require
# 1. A Google Account to save your data
# 2. A folder in your Google Drive containing<br>
#   a) RunTable file<br>This file should contain the list of RunIDs that you want to download from ENA ([example]())<br>
#   b) CDS file of the organism that you are interested to work with
#
# ### Expected outputs
# 1. Kallisto index of your organism's CDS<br>
# 2. Kallisto output folders<br>
# 3. Download report<br>Summarises for each RunID the status of download, amount of data downloaded, amount of time taken for kallisto streaming and a statistics from kallisto
#
#
# ### Bonus tips?
# 1. If you noticed that the file has not been downloaded successfully ("Download speed/time not accepted"), not to worry, the script will attempt to download it again.
# 2. Download got interrupted due to runtime disconnecting? Just re-run the script with 'Option B' (Step 1.2, part 5) and specify the date when you started the download.
# 3. If you encoutner any issues, please raise an issue on [Github](https://github.com/tqiaowen/LSTrAP-Cloud) or contact us [here](mailto:qiaowen001@e.ntu.edu.sg).

# %%
#@markdown ####1.1 Mount Google Drive and import python modules

#Mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# !rm -rf /content/sample_data

#Import modules
import os
import time
from datetime import datetime as dt
import scipy.stats as stats
import json
import math
import re
import ast
import datetime
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ####User input of variables

# %%
#@title 1.2 Input form {display-mode: "form"}

#@markdown 1) Enter the absolute path for the folder you are going to work with. Tip: After mounting your Google Drive, right click on the file and copy path.<br>
#@markdown <html><img src = 'https://github.com/tqiaowen/LSTrAP-Cloud/blob/master/img/folder_path.png?raw=true', alt = 'Copy file path' width=360 height=287></html>

in_dir = '/content/gdrive/My Drive/Projects/William_2019/Nta_Edward' #@param {type: 'string'}

#@markdown ---

#@markdown 2) Enter the species name. Eg. _Nicotiana tabacum_ can be shortened to **Nta**

species_name = 'Nta' #@param {type: 'string'}

#@markdown ---

#@markdown 3) File name for Run Table (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**runid_Nta.txt**_'

RunTable_file = 'runid_Nta.txt' #@param {type: 'string'}

#@markdown ---

#@markdown 4) File name for CDS file (with extension), stored in Google Drive folder as indicated in step 1.

#@markdown Eg: '_**GCF_000715135.1_Ntab-TN90_cds_from_genomic.fna.gz**_'

cds_fasta_file = 'Nitab-v4.5_cDNA_Edwards2017.fasta' #@param {type: 'string'}

#@markdown ---

#@markdown 5) Specify download mode

download_mode = "B. Continue from previous run" #@param ["A. Start fresh run", "B. Continue from previous run"]
download_mode = download_mode[0]

if download_mode == "B":
  Date_initiated = '2020-02-14' #@param {type: 'date'}
  date = Date_initiated

# %%
#@markdown 1.3 Install Dependencies, Initialise Variables and Directories

#Create Dependencies directory
if os.path.exists('/content/Dependencies') == False:
  os.mkdir('/content/Dependencies')
  os.chdir('/content/Dependencies')
  print('Dependencies directory created.')
  #Download and install kallisto
  os.system('wget \'https://github.com/pachterlab/kallisto/releases/download/v0.46.0/kallisto_linux-v0.46.0.tar.gz\'')
  os.system('tar -xf kallisto_linux-v0.46.0.tar.gz')
  if os.path.exists('kallisto/kallisto'):
    print('kallisto installed.')
    # !cp kallisto/kallisto /bin/kallisto
  else:
    print('kallisto not found.')

#Define paths
working_dir_path = "/content/gdrive/My Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
working_dir_path_ter = "/content/gdrive/My\ Drive/" + in_dir.split('/content/gdrive/My Drive/')[1] + "/"
  #Note: "\(whitespace)" is needed when we are calling shell command as a string via os.system
RunTablePath = working_dir_path + RunTable_file
cds_fasta_path = working_dir_path_ter + cds_fasta_file    

#Make new directory for this execution of the script if user chooses option "A"
os.chdir(working_dir_path)

if download_mode == "A":
  date = str(dt.now().date())
  files = os.listdir(working_dir_path)
  try:
      os.mkdir(working_dir_path + date + "_01")
      print(date + "_01 directory has been created.") 
  except FileExistsError:
      filename = max([filename for filename in files if date in filename])
      file_serial_int = int(filename[-2:]) + 1
      if 1 < file_serial_int < 10:
          file_serial_str = "0" + str(file_serial_int)
      elif 10 <= file_serial_int < 100:
          file_serial_str = str(file_serial_int)
          
      os.mkdir(working_dir_path + date + "_" + file_serial_str)
      print(date + "_" + file_serial_str + " directory has been created.")
  except:
      print("Directory failed to be created.")

#Calls the most recent directory
#Will start from here for Option "B"
files = os.listdir(working_dir_path)
filename = max([filename for filename in files if date in filename])
execution_dir_path = working_dir_path + filename + "/"
execution_dir_path_ter = working_dir_path_ter + filename + "/"

#Download report
#Create a tab-separated .txt logfile that stores time and progress in this workflow
os.chdir(execution_dir_path)
#species_name = (RunTablePath.split('/')[-1]).split('_',1)[1][:-4]
download_report_name = "Download_report_" + species_name + "_" + date + ".txt"

if os.path.exists(download_report_name):
  pass
  #For Option B, Download report will be read later in the for loop

else:
  #Create new download report
  download_report = open(download_report_name, "a+")
  download_report.write("Run ID\tLibrary Layout\tStatus\tFile size\tTimestamp\tKallisto time (s)\tn_processed\tn_pseudoaligned\tp_pseudoaligned\t%genes mapped\n")
  download_report.close()
# Out:
# Dependencies directory created.
# kallisto installed.

# %%
#@markdown 1.4 Create kallisto index
kallisto_index_path_ter = execution_dir_path_ter + "index_file_" + species_name #to be created by kallisto
kallisto_index_path = execution_dir_path + "index_file_" + species_name

if os.path.exists(kallisto_index_path):
  print("Kallisto index already present for " + species_name + ".")
else:
  index_start = time.time()
  # os.system(kallisto_path + " index -i " + kallisto_index_path_ter + " " + cds_fasta_path)
  # !kallisto index -i $kallisto_index_path_ter $cds_fasta_path
  if os.path.exists(kallisto_index_path):
    print("Kallisto index created for " + species_name + ".")
    print("Time to create kallisto index:", time.time()-index_start)
  else:
    print("Kallisto index not found for " + species_name + ".")
# Out:
# Kallisto index already present for Nta.

# %%
#@markdown 1.5 Preparation for download<br>
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.1 Initialise download functions</html>
#Functions#############################################################

def get_ftp_links(RunID):
  '''(str)->(str,str)
  Return ftp link in the paired and unpaired format for the RunID specified
  '''
  dir2 = ""
  if 9 < len(RunID) <= 12:
      dir2 = "0"*(12 - len(RunID)) + RunID[-(len(RunID)-9):] + "/"
  dirs = RunID[:6] + "/" + dir2 + RunID
  ftp_link_paired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + "_1.fastq.gz"
  ftp_link_unpaired = "ftp://ftp.sra.ebi.ac.uk/vol1/fastq/" + dirs + "/" + RunID + ".fastq.gz"
  return ftp_link_paired, ftp_link_unpaired

######################################################################

def dlsize(RunID):
  """(str)->(str)
  Returns size of downloaded file obtained from the log
  """
  ll= open(RunID +".log", "r").readlines()[-1].split(" ")
  con = []
  for i in ll:
    if i != '':
      con.append(i)
    if len(con) >= 4:
      break
  return con[-1]

######################################################################

def kallisto_stream(RunID):
  '''(str)->(float,str,str,str,str)
  Runs kallisto quant on streamed fastq file for each RunID, streaming the unpaired file first. If streaming for unpaired file fails, streaming will be attempted for paired file.
  If both streaming for unpaired and paired files are unsuccessful, i.e. curl: (78) RETR response: 550; file probably does not exist on server and subsequent attempts will be aborted.
  For streaming (curl command):
    Streams only the first 1M bytes of data.
    Ensures that:
      Download speed not < 1x10^9 Bytes for 30 s
      Maximum time taken = 600 s = 10 min
    If these speed/time are not met, download is terminated and restarted for a total of 3 tries.
  '''
  RunID_file_path = execution_dir_path + RunID + "/"
  paired, unpaired = get_ftp_links(RunID)
  layout = "Layout unknown"
  for i in range(3): #try downloading at most 3 times
    kallisto_start = time.time()
    timestamp = datetime.datetime.now()
    # Dl first 1m bytes, max time 600s, speed limit ~1gb for 30s, send stderr to RunID.log
    if layout == "Paired":
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
    else:
      # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $unpaired 2> $RunID'.log')
      if 'curl: (78)' not in open(RunID + '.log','r').read():
       layout = "Single"
      else:
        # !kallisto quant -i $kallisto_index_path_ter -o $RunID --single -l 200 -s 20 -t 2 <(curl -L -r 0-1000000000 -m 600 --speed-limit 1000000 --speed-time 30 $paired 2> $RunID'.log')
        if 'curl: (78)' or 'denied' in open(RunID + '.log','r').read():
          size = dlsize(RunID)
          # !rm $RunID".log"
          print(RunID + '[i=' + str(i) + ']: File not found. Download aborted.')
          layout = "N/A"
          status = "File not found"
          kallisto_end = time.time()
          break
        layout = "Paired"
    kallisto_end = time.time()

    #check for stderr logs, if absent, first 1GB file download is complete
    size = dlsize(RunID)
    if 'curl: (28)' not in open(RunID + '.log','r').read(): #if no slow dl speed error, acccept 
      # !rm $RunID".log"
      status = "Downloaded"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is acceptable.')
      break
    
    if RunID + '.log' in os.listdir(execution_dir_path): #remove stderr log file before contining to the next attempt of download
      # !cp $RunID".log" $RunID"_copy.log"
      # !rm $RunID".log"
      status = "Download speed/time not accepted"
      print(RunID + '[i=' + str(i) + ']: Download speed/time is not accepted.')
  
  #If download still incomplete, use the last file saved
  kallisto_time = round(kallisto_end - kallisto_start, 4)
  
  return kallisto_time, layout, status, size, timestamp

######################################################################

def get_ListOfRunID(RunTablePath):
  with open(RunTablePath,"r") as RunTable:
    ListOfRunID = [RunID.strip().upper() for RunID in RunTable.readlines()]
  if "RUNID" in ListOfRunID[0]: #If input file has header, exclude header
    ListOfRunID = ListOfRunID[1:]
  return ListOfRunID

######################################################################

def open_download_report():
  with open(download_report_name, "r") as download_report:
    download_lines = download_report.readlines()
  download_entries = [line.strip().split("\t") for line in download_lines]

  return download_lines, download_entries

######################################################################

def get_comments_index(download_lines):
  hex_line_indices = [download_lines.index(line) for line in download_lines if "#" in line]
  started_indices = [index for index in hex_line_indices if "started" in download_lines[index]]
  completed_indices = [index for index in hex_line_indices if "completed" in download_lines[index]]

  return hex_line_indices, started_indices, completed_indices

######################################################################

def get_failed_RunID(mode_type):
  '''
  Opens Download Report;
  Collate failed RunIDs from the latest COMPLETED j loop.
  '''
  if mode_type == "A": #CALLED WHEN MOVING ON TO THE NEXT J LOOP
    started_index = -1
  elif mode_type == "B": #CALLED WHEN REDOWNLOADING (j=1 or 2) WITH MODE B
    started_index = -2
  #Need to reopen download report to compile failed RunIDs
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  
  j_head_index = started_indices[started_index] # If 1<=j<=2, then 2<=len(started_indices)<=3

  # Find failed RunIDs within last completed j loop, in chronological order
  list_of_failed_RunID = []
  for index in range(j_head_index, completed_indices[-1]):
    if index not in hex_line_indices and download_entries[index][2] == "Download speed/time not accepted":
      list_of_failed_RunID.append(download_entries[index][0])

  return list_of_failed_RunID

######################################################################


def get_j():
  '''
  Get the current j loop download was paused at.
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)
  j = len(completed_indices)
  return j

######################################################################

def get_RunID_start(RunID_queue):
  '''
  * CALLED ONCE WHEN REDOWNLOADING WITH MODE B ONLY *

  Checks from the bottom of Download Report upwards until the lastest #start.
  Takes the latest RunID.
  RunID_start_index will be the index of the next RunID in RunID_queue.
  If all RunID in queue completed, index will simply = to len(RunID_queue),
  will move on to next j loop
  '''
  download_lines, download_entries = open_download_report()
  hex_line_indices, started_indices, completed_indices = get_comments_index(download_lines)

  for i in range((len(download_entries) - 1), (started_indices[-1]), -1):
    if i not in hex_line_indices:
      RunID_latest = download_entries[i][0]
      break

  try:
    RunID_start_index = RunID_queue.index(RunID_latest) + 1
  except:
    RunID_start_index = 0 # len(RunID_queue) will also be 0, move on to next j loop. 
    print("No RunID_start_index generated.")

  return RunID_start_index

######################################################################

def update_download_report(to_print):
  with open(download_report_name, "a+") as download_report:
    download_report.write(to_print)

######################################################################

def json_extract(RunID_file_path):
  """(str)->(str,str,str,str,str)
  Extracts info from run_info.json
  """
  kal_json = ast.literal_eval(open(RunID_file_path + "run_info.json", "r").read())
  n_processed = str(kal_json["n_processed"])
  n_pseudoaligned = str(kal_json["n_pseudoaligned"])
  p_pseudoaligned = str(kal_json["p_pseudoaligned"])
  return n_processed, n_pseudoaligned, p_pseudoaligned

######################################################################

def abundance(RunID_file_path):
  """(str)->(str)
  Computes percentage of genes mapped
  """
  with open(RunID_file_path + "abundance.tsv", "r") as abun:
    abun.readline()
    tpmlist = [line.strip("\n").split("\t")[-1] for line in abun.readlines()]
    tpmval = [val for val in tpmlist if val != "0" and val != "-nan"]
    return str(round((len(tpmval)/len(tpmlist))*100 , 1)) + "%"

######################################################################

def download_loop(RunID_start_index, RunID_queue):
  '''
  Execute inner download_loop i=3 for all RunIDs in RunID_queue;
  Updates download report as each RunID is processed.
  '''
  for index in range(RunID_start_index, len(RunID_queue)):
    RunID = RunID_queue[index]
    print()
    print("-"*40)
    print()
    job_queue = index + 1
    total_queue = len(RunID_queue)
    print('Processing ' + str(job_queue) + "/" + str(total_queue) + ": " + RunID)

    RunID_file_path = execution_dir_path + RunID + "/"
    if os.path.exists(RunID_file_path) == False:
      os.mkdir(RunID_file_path) #Directory to store kallisto files of each RunID
    download_status = [RunID, "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A", "N/A"]
    '''
    *Download Report Headers*
    Run ID | Library Layout | Status | File size | Timestamp | Kallisto time(s) | n_processed | n_pseudoaligned | p_pseudoaligned | %genes mapped

    *Possible output for "Method"*
    download_status[2]
      "N/A" -> No streaming attempted yet
      "Downloaded" -> Successfully streamed and quantify single/paired-end data
      "File not found" -> FASTQ file not found on server
      "Download speed/time not accepted" -> Failed to stream at a satisfactory speed
    '''
    #Streaming method
    kallisto_time, layout, status, size, timestamp = kallisto_stream(RunID)
    if os.path.exists(RunID_file_path + "run_info.json"):
      download_status[1] = layout
      download_status[2] = status
      download_status[3] = size
      download_status[4] = str(timestamp)
      download_status[5] = str(kallisto_time)
      n_processed, n_pseudoaligned, p_pseudoaligned = json_extract(RunID_file_path)
      download_status[6] = n_processed
      download_status[7] = n_pseudoaligned
      download_status[8] = p_pseudoaligned
      download_status[9] = abundance(RunID_file_path)

    else:
      print(RunID + ": Missing kallisto output")

    update_download_report("\t".join(download_status) + "\n")

  return True

######################################################################

def stringS(col, val):
  collist = [7, 12, 10,16]
  length = collist[col] - len(str(val))
  return int(length/2)*" "+str(val)+round(length/2)*" "+"|"

######################################################################
#@markdown <html>&nbsp&nbsp&nbsp&nbsp&nbsp1.5.2 Updating list of RunIDs to be downloaded</html>
ListOfRunID = get_ListOfRunID(RunTablePath)

# Specify variables for mode A or B

if download_mode == "A":
  j, RunID_start_index = 0, 0
  RunID_queue = ListOfRunID

elif download_mode == "B":
  j = get_j()

  if j == 3:
    RunID_queue = [] #End download. j loop completed thrice.
  else:
    if j == 0:
      RunID_queue = ListOfRunID
    elif 1 <= j <= 2:
      RunID_queue = get_failed_RunID(download_mode)
    if RunID_queue == []: # End j loop if no more failed RunID.
      j = 3
  
  RunID_start_index = get_RunID_start(RunID_queue)
  update_download_report("#Download resumed\n")

# %%
#@markdown 1.6 Loop to download experiments according to updated list of runIDs

# Loop through j x i times down the RunID_queue

for loop in range(j,3):
  print("\n" + "-"*40 + "\n")
  if RunID_start_index == 0:
    print("Download attempt %s"%(loop+1))
    update_download_report("#Download attempt %s started\n" % (loop+1))
  else:
    print("Download attempt %s resumed"%(j+1))
  
  download_loop(RunID_start_index, RunID_queue)
  update_download_report("#Download attempt %s completed\n" % (loop+1))

  #Reset RunID_start_index and RunID_queue
  RunID_start_index = 0
  RunID_queue = get_failed_RunID("A")
  if RunID_queue == []: # End j loop if no more failed RunID.
      print("All RunIDs have been successfully downloaded.")
      break
print("Download complete.")
with open(download_report_name, "r") as download_report:
  file_content = download_report.read()
  file_error = [(a.start(),a.end()) for a in list(re.finditer('File not found', file_content))]
  file_success = [(a.start(),a.end()) for a in list(re.finditer('Downloaded', file_content))]
  print("| Total | Downloaded | Rejected | File not found |\n|"\
        + stringS(0,len(get_ListOfRunID(RunTablePath)))\
        + stringS(1,len(file_success))\
        + stringS(2,len(get_ListOfRunID(RunTablePath))-len(file_success)-len(file_error))\
        + stringS(3,len(file_error)))
# Out:
# Streaming output truncated to the last 5000 lines.
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x29e2000 @  0x7f5e6d8751e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5e6c891b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,107,015 reads, 7,658,276 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 542 rounds
#
# SRR2023683[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 108/1060: SRR2023686
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2c24000 @  0x7fbb18f1f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fbb17f3bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x287e000 @  0x7effe0eb71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7effdfed3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,188,604 reads, 7,801,837 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 669 rounds
#
# SRR2023686[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 109/1060: SRR2023688
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1e92000 @  0x7f82b884e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f82b786ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a72000 @  0x7fe002d6d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fe001d89b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,224,289 reads, 7,861,285 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 338 rounds
#
# SRR2023688[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 110/1060: SRR2023691
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2cf2000 @  0x7f3622e9a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3621eb6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20aa000 @  0x7f2ec06421e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2ebf65eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,136,754 reads, 7,720,208 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 503 rounds
#
# SRR2023691[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 111/1060: SRR2023789
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2686000 @  0x7f7309e801e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7308e9cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2868000 @  0x7f8e4d7921e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8e4c7aeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,055,018 reads, 7,869,700 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 369 rounds
#
# SRR2023789[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 112/1060: SRR2023937
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1356000 @  0x7fc32ebf21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc32dc0eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x14e0000 @  0x7f3df8c8d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3df7ca9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,197,764 reads, 8,016,516 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 436 rounds
#
# SRR2023937[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 113/1060: SRR2024068
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x23cc000 @  0x7f7aa07221e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7a9f73eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x27ec000 @  0x7fcd21e4c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fcd20e68b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,238,881 reads, 7,453,803 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 425 rounds
#
# SRR2024068[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 114/1060: SRR2024164
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x202c000 @  0x7fd5beec21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd5bdedeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x238e000 @  0x7f8da08371e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8d9f853b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,143,644 reads, 7,380,202 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 518 rounds
#
# SRR2024164[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 115/1060: SRR2024203
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17d4000 @  0x7f0026f651e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0025f81b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x28b6000 @  0x7ff440d401e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff43fd5cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,125,386 reads, 7,809,222 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 373 rounds
#
# SRR2024203[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 116/1060: SRR2024204
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1bca000 @  0x7f2a80cd01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2a7fcecb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2f12000 @  0x7fda421431e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fda4115fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,205,137 reads, 7,694,809 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 510 rounds
#
# SRR2024204[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 117/1060: SRR2024205
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3152000 @  0x7f7126ad81e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f7125af4b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x29d0000 @  0x7f453345e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f453247ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,192,326 reads, 7,808,616 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 297 rounds
#
# SRR2024205[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 118/1060: SRR2064998
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ef2000 @  0x7f9ff10d41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9ff00f0b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2dee000 @  0x7fb55298d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb5519a9b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,036,223 reads, 6,582,852 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 447 rounds
#
# SRR2064998[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 119/1060: SRR4253227
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x233c000 @  0x7faf281231e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7faf2713fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20ec000 @  0x7f8d27ce41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8d26d00b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,572,748 reads, 7,635,420 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 305 rounds
#
# SRR4253227[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 120/1060: SRR4253239
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1afa000 @  0x7f37b7ad31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f37b6aefb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17fe000 @  0x7f63286f31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f632770fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,527,794 reads, 8,932,819 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 422 rounds
#
# SRR4253239[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 121/1060: SRR4253245
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2180000 @  0x7f354c4e01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f354b4fcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x296e000 @  0x7f585b4be1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f585a4dab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,584,329 reads, 8,545,425 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 388 rounds
#
# SRR4253245[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 122/1060: SRR3990792
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1852000 @  0x7f80d92f11e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f80d830db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 1,525,178 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR3990792[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 123/1060: SRR3990793
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2488000 @  0x7f49e73891e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f49e63a5b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 1,131,135 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR3990793[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 124/1060: SRR5205590
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x17ca000 @  0x7f46c33691e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f46c2385b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x313e000 @  0x7f3f4327c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f3f42298b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,046,039 reads, 8,804,869 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 485 rounds
#
# SRR5205590[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 125/1060: SRR5205591
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a88000 @  0x7f89c42ce1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f89c32eab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x31ee000 @  0x7fb4d41ca1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb4d31e6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,035,256 reads, 8,935,618 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 428 rounds
#
# SRR5205591[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 126/1060: SRR5205592
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x13fe000 @  0x7f86cdc971e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f86cccb3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1384000 @  0x7f4241c3f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4240c5bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,031,558 reads, 8,408,958 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 408 rounds
#
# SRR5205592[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 127/1060: SRR5205593
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x16b0000 @  0x7fde1da231e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fde1ca3fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1b14000 @  0x7f82cdbc61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f82ccbe2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,989,855 reads, 8,520,901 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 355 rounds
#
# SRR5205593[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 128/1060: SRR5205594
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2b80000 @  0x7f45068181e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4505834b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1980000 @  0x7f4790ef21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f478ff0eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,405,256 reads, 9,162,106 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 430 rounds
#
# SRR5205594[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 129/1060: SRR5205595
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x136c000 @  0x7f273a5e61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2739602b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x287e000 @  0x7ff4b0ed21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff4afeeeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,329,556 reads, 9,118,221 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 373 rounds
#
# SRR5205595[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 130/1060: SRR5205596
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1342000 @  0x7f9268b4b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9267b67b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2086000 @  0x7f9a96c551e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9a95c71b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,426,060 reads, 8,844,776 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 426 rounds
#
# SRR5205596[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 131/1060: SRR5205597
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2570000 @  0x7fdaf2e1d1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fdaf1e39b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20c6000 @  0x7f0d23c781e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0d22c94b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,407,684 reads, 9,035,347 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 393 rounds
#
# SRR5205597[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 132/1060: SRR4013045
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x20f2000 @  0x7f85f9f441e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f85f8f60b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2182000 @  0x7f12b32f81e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f12b2314b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,537,088 reads, 8,057,977 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# SRR4013045[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 133/1060: SRR4013046
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3006000 @  0x7fc2069161e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc205932b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ece000 @  0x7ff968fe31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ff967fffb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 11,724,536 reads, 8,184,554 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 373 rounds
#
# SRR4013046[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 134/1060: SRR4013047
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1872000 @  0x7fa76e4411e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa76d45db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1758000 @  0x7f48e9d511e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f48e8d6db97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,590,478 reads, 7,891,957 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 507 rounds
#
# SRR4013047[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 135/1060: SRR4013048
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1366000 @  0x7f6c9f2871e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6c9e2a3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x25b4000 @  0x7f4bbf3eb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4bbe407b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,627,465 reads, 7,593,275 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 546 rounds
#
# SRR4013048[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 136/1060: SRR4013049
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1c82000 @  0x7fba2ffd21e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fba2efeeb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x24c0000 @  0x7fbf870021e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fbf8601eb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,172,087 reads, 7,074,044 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 483 rounds
#
# SRR4013049[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 137/1060: SRR4013050
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x15ce000 @  0x7fc9ef4fe1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc9ee51ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1dde000 @  0x7f0f789791e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f0f77995b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,585,446 reads, 7,655,771 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 429 rounds
#
# SRR4013050[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 138/1060: SRR4013051
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x305e000 @  0x7fb9f06bf1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb9ef6dbb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x15f6000 @  0x7f48cb7b51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f48ca7d1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,574,206 reads, 7,287,050 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 540 rounds
#
# SRR4013051[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 139/1060: SRR4013052
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x26f2000 @  0x7facdb5831e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7facda59fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2968000 @  0x7f2bbc36c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f2bbb388b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 10,280,847 reads, 7,225,023 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 507 rounds
#
# SRR4013052[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 140/1060: SRR4013053
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x24ac000 @  0x7f1e6b4a31e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1e6a4bfb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# ...
#
# ----------------------------------------
#
# Processing 280/1060: SRR3099655
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x22e4000 @  0x7f85f2ebb1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f85f1ed7b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 4,806,609 reads, 3,607,984 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 355 rounds
#
# SRR3099655[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 281/1060: SRR3100097
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1e12000 @  0x7f1eabf531e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f1eaaf6fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 3,411,949 reads, 2,553,405 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 330 rounds
#
# SRR3100097[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 282/1060: SRR3100098
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1f1e000 @  0x7fb35869a1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb3576b6b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 3,411,949 reads, 2,555,294 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 338 rounds
#
# SRR3100098[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 283/1060: SRR3100099
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2472000 @  0x7f154efb51e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f154dfd1b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 3,331,796 reads, 2,382,140 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 461 rounds
#
# SRR3100099[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 284/1060: SRR3100795
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x28ca000 @  0x7fef53d241e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fef52d40b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2274000 @  0x7fb122db71e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fb121dd3b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,412,852 reads, 8,963,945 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 482 rounds
#
# SRR3100795[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 285/1060: SRR4039543
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x206e000 @  0x7fcb5cd3f1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fcb5bd5bb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x15a8000 @  0x7fd595a431e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fd594a5fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,782,680 reads, 9,162,171 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 419 rounds
#
# SRR4039543[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 286/1060: SRR4039544
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x25e0000 @  0x7f4ffadd61e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4ff9df2b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1a48000 @  0x7f8659e091e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f8658e25b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,817,251 reads, 9,304,273 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 518 rounds
#
# SRR4039544[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 287/1060: SRR4039545
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2b06000 @  0x7fa08b5fc1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fa08a618b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3170000 @  0x7fc42d93e1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fc42c95ab97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,796,688 reads, 9,225,618 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 584 rounds
#
# SRR4039545[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 288/1060: SRR4039547
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x3044000 @  0x7ffb10f371e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7ffb0ff53b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x25e2000 @  0x7f81e27471e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f81e1763b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,815,935 reads, 8,960,757 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 483 rounds
#
# SRR4039547[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 289/1060: SRR4039548
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ee4000 @  0x7f4b4fee01e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f4b4eefcb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 0 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x1ec0000 @  0x7f6d562801e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f6d5529cb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 12,882,229 reads, 9,228,052 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 567 rounds
#
# SRR4039548[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 290/1060: SRR5485035
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2236000 @  0x7f5d2aa141e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f5d29a30b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 9,944,651 reads, 5,474,087 reads pseudoaligned
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 613 rounds
#
# SRR5485035[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 291/1060: SRR638990
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2df8000 @  0x7f9ce55431e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9ce455fb97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 3,672,456 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR638990[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 292/1060: SRR638991
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x2572000 @  0x7f44c3eb41e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f44c2ed0b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 3,705,287 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR638991[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 293/1060: SRR638992
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x329a000 @  0x7fac0505b1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7fac04077b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 3,721,832 reads, 0 reads pseudoaligned
# [~warn] no reads pseudoaligned.
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 52 rounds
#
# SRR638992[i=0]: Download speed/time is acceptable.
#
# ----------------------------------------
#
# Processing 294/1060: SRR638993
#
# [quant] fragment length distribution is truncated gaussian with mean = 200, sd = 20
# [index] k-mer length: 31
# [index] number of targets: 69,500
# [index] number of k-mers: 61,223,759
# tcmalloc: large alloc 1610612736 bytes == 0x215a000 @  0x7f9d7811c1e7 0x6f181d 0x6f1899 0x4acad9 0x4a6c50 0x44ec75 0x7f9d77138b97 0x452a59
# [index] number of equivalence classes: 224,789
# [quant] running in single-end mode
# [quant] will process file 1: /dev/fd/63
# [quant] finding pseudoalignments for the reads ...
